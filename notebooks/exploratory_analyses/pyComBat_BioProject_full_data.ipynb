# %% [markdown]
# Purpose: Correct the full dataset for BioProject batch effects using pyComBat.<br>
# Author: Anna Pardo<br>
# Date initiated: March 1, 2024

# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from combat.pycombat import pycombat

# %%
# load TPM matrix
tpm = pd.read_csv("../../data/rawtpm_bptreat_noPEG.tsv",sep="\t",header="infer")
tpm.head()
# Out:
#         Sample   BioProject Treatment  Zm00001eb000010  Zm00001eb000020  \
# 0  SRR11933261  PRJNA637522   Drought        12.553818         2.321077
# 1  SRR11933272  PRJNA637522   Drought        16.255838         3.110372
# 2  SRR11933250  PRJNA637522   Drought         9.028815         2.984479
# 3  SRR11933029  PRJNA637522   Control         8.201340         2.385748
# 4  SRR11933040  PRJNA637522   Drought        10.371251         2.799099
#
#    Zm00001eb000050  Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# 0         0.042520        12.932676         5.253755        11.105837
# 1         0.405226         7.214039         1.902461         2.346186
# 2         0.000000         3.092442         2.586555        16.186141
# 3         0.000000         1.726808         1.926412        19.600487
# 4         0.000000         1.280629         3.771234        19.717683
#
#    Zm00001eb000100  ...  Zm00001eb442810  Zm00001eb442820  Zm00001eb442840  \
# 0         0.409268  ...         0.171184         0.000000              0.0
# 1         0.170305  ...         0.108052         0.127878              0.0
# 2         0.000000  ...         0.000000         0.000000              0.0
# 3         0.000000  ...         0.000000         0.000000              0.0
# 4         0.143764  ...         0.178304         0.012158              0.0
#
#    Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  Zm00001eb442910  \
# 0              0.0              0.0         0.309501              0.0
# 1              0.0              0.0         6.703281              0.0
# 2              0.0              0.0         0.417565              0.0
# 3              0.0              0.0         0.000000              0.0
# 4              0.0              0.0         9.625225              0.0
#
#    Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0         0.000000              0.0         0.000000
# 1         0.000000              0.0         0.000000
# 2         0.254123              0.0         1.213349
# 3         0.000000              0.0         1.370075
# 4         0.000000              0.0         2.352959
#
# [5 rows x 39007 columns]

# %%
# define a function from an answer in https://stackoverflow.com/questions/39812885/retain-feature-names-after-scikit-feature-selection
def variance_threshold_selector(data):
    selector = VarianceThreshold()
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
# set Sample as index and drop BioProject and Treatment columns
ttpm = tpm.set_index("Sample").drop(["BioProject","Treatment"],axis=1)
ttpm.head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261        12.553818         2.321077         0.042520
# SRR11933272        16.255838         3.110372         0.405226
# SRR11933250         9.028815         2.984479         0.000000
# SRR11933029         8.201340         2.385748         0.000000
# SRR11933040        10.371251         2.799099         0.000000
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261        12.932676         5.253755        11.105837
# SRR11933272         7.214039         1.902461         2.346186
# SRR11933250         3.092442         2.586555        16.186141
# SRR11933029         1.726808         1.926412        19.600487
# SRR11933040         1.280629         3.771234        19.717683
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.409268              0.0         1.122904
# SRR11933272         0.170305              0.0         2.280915
# SRR11933250         0.000000              0.0         1.908468
# SRR11933029         0.000000              0.0         1.619452
# SRR11933040         0.143764              0.0         2.264390
#
#              Zm00001eb000140  ...  Zm00001eb442810  Zm00001eb442820  \
# Sample                        ...
# SRR11933261              0.0  ...         0.171184         0.000000
# SRR11933272              0.0  ...         0.108052         0.127878
# SRR11933250              0.0  ...         0.000000         0.000000
# SRR11933029              0.0  ...         0.000000         0.000000
# SRR11933040              0.0  ...         0.178304         0.012158
#
#              Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  \
# Sample
# SRR11933261              0.0              0.0              0.0
# SRR11933272              0.0              0.0              0.0
# SRR11933250              0.0              0.0              0.0
# SRR11933029              0.0              0.0              0.0
# SRR11933040              0.0              0.0              0.0
#
#              Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# Sample
# SRR11933261         0.309501              0.0         0.000000
# SRR11933272         6.703281              0.0         0.000000
# SRR11933250         0.417565              0.0         0.254123
# SRR11933029         0.000000              0.0         0.000000
# SRR11933040         9.625225              0.0         0.000000
#
#              Zm00001eb442980  Zm00001eb443030
# Sample
# SRR11933261              0.0         0.000000
# SRR11933272              0.0         0.000000
# SRR11933250              0.0         1.213349
# SRR11933029              0.0         1.370075
# SRR11933040              0.0         2.352959
#
# [5 rows x 39004 columns]

# %%
# put through VarianceThreshold() using the variance_threshold_selector() defined above
vttpm = variance_threshold_selector(ttpm)
vttpm.head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261        12.553818         2.321077         0.042520
# SRR11933272        16.255838         3.110372         0.405226
# SRR11933250         9.028815         2.984479         0.000000
# SRR11933029         8.201340         2.385748         0.000000
# SRR11933040        10.371251         2.799099         0.000000
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261        12.932676         5.253755        11.105837
# SRR11933272         7.214039         1.902461         2.346186
# SRR11933250         3.092442         2.586555        16.186141
# SRR11933029         1.726808         1.926412        19.600487
# SRR11933040         1.280629         3.771234        19.717683
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.409268              0.0         1.122904
# SRR11933272         0.170305              0.0         2.280915
# SRR11933250         0.000000              0.0         1.908468
# SRR11933029         0.000000              0.0         1.619452
# SRR11933040         0.143764              0.0         2.264390
#
#              Zm00001eb000140  ...  Zm00001eb442810  Zm00001eb442820  \
# Sample                        ...
# SRR11933261              0.0  ...         0.171184         0.000000
# SRR11933272              0.0  ...         0.108052         0.127878
# SRR11933250              0.0  ...         0.000000         0.000000
# SRR11933029              0.0  ...         0.000000         0.000000
# SRR11933040              0.0  ...         0.178304         0.012158
#
#              Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  \
# Sample
# SRR11933261              0.0              0.0              0.0
# SRR11933272              0.0              0.0              0.0
# SRR11933250              0.0              0.0              0.0
# SRR11933029              0.0              0.0              0.0
# SRR11933040              0.0              0.0              0.0
#
#              Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# Sample
# SRR11933261         0.309501              0.0         0.000000
# SRR11933272         6.703281              0.0         0.000000
# SRR11933250         0.417565              0.0         0.254123
# SRR11933029         0.000000              0.0         0.000000
# SRR11933040         9.625225              0.0         0.000000
#
#              Zm00001eb442980  Zm00001eb443030
# Sample
# SRR11933261              0.0         0.000000
# SRR11933272              0.0         0.000000
# SRR11933250              0.0         1.213349
# SRR11933029              0.0         1.370075
# SRR11933040              0.0         2.352959
#
# [5 rows x 38995 columns]

# %%
# log-transform TPM
vttpm_log = vttpm.apply(lambda x: np.log2(x+1))
vttpm_log.head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261         3.760627         1.731651         0.060075
# SRR11933272         4.109013         2.039269         0.490802
# SRR11933250         3.326079         1.994391         0.000000
# SRR11933029         3.201844         1.759475         0.000000
# SRR11933040         3.507319         1.925657         0.000000
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261         3.800400         2.644723         3.597631
# SRR11933272         3.038092         1.537277         1.742518
# SRR11933250         2.032962         1.842599         4.103174
# SRR11933029         1.447213         1.549133         4.364607
# SRR11933040         1.189432         2.254362         4.372791
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.494946              0.0         1.086039
# SRR11933272         0.226885              0.0         1.714098
# SRR11933250         0.000000              0.0         1.540259
# SRR11933029         0.000000              0.0         1.389265
# SRR11933040         0.193789              0.0         1.706813
#
#              Zm00001eb000140  ...  Zm00001eb442810  Zm00001eb442820  \
# Sample                        ...
# SRR11933261              0.0  ...         0.227968         0.000000
# SRR11933272              0.0  ...         0.148026         0.173611
# SRR11933250              0.0  ...         0.000000         0.000000
# SRR11933029              0.0  ...         0.000000         0.000000
# SRR11933040              0.0  ...         0.236712         0.017435
#
#              Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  \
# Sample
# SRR11933261              0.0              0.0              0.0
# SRR11933272              0.0              0.0              0.0
# SRR11933250              0.0              0.0              0.0
# SRR11933029              0.0              0.0              0.0
# SRR11933040              0.0              0.0              0.0
#
#              Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# Sample
# SRR11933261         0.389017              0.0         0.000000
# SRR11933272         2.945473              0.0         0.000000
# SRR11933250         0.503415              0.0         0.326679
# SRR11933029         0.000000              0.0         0.000000
# SRR11933040         3.409421              0.0         0.000000
#
#              Zm00001eb442980  Zm00001eb443030
# Sample
# SRR11933261              0.0         0.000000
# SRR11933272              0.0         0.000000
# SRR11933250              0.0         1.146231
# SRR11933029              0.0         1.244933
# SRR11933040              0.0         1.745435
#
# [5 rows x 38995 columns]

# %%
# Load metadata
md = pd.read_csv("../../data/metadata_corrected_14-Feb-2024.csv",sep=",",header="infer")
md.head()
# Out:
#    Unnamed: 0   BioProject       Sample sample_name  Replicate_num Genotype  \
# 0           0  PRJNA637522  SRR11933261     238_WS2            NaN      238
# 1           1  PRJNA637522  SRR11933272     238_WS1            NaN      238
# 2           2  PRJNA637522  SRR11933250     268_WS1            NaN      268
# 3           3  PRJNA637522  SRR11933029      268_WW            NaN      268
# 4           4  PRJNA637522  SRR11933040     268_WS2            NaN      268
#
#             Technology Library_layout Treatment  Duration_hours  ...  \
# 0  Illumina HiSeq 2500         PAIRED   Drought           312.0  ...
# 1  Illumina HiSeq 2500         PAIRED   Drought           216.0  ...
# 2  Illumina HiSeq 2500         PAIRED   Drought           216.0  ...
# 3  Illumina HiSeq 2500         PAIRED   Control           216.0  ...
# 4  Illumina HiSeq 2500         PAIRED   Drought           312.0  ...
#
#   Developmental_stage  Tissue Day_length_hours Day_temp_C Night_temp_C  \
# 0                  V3    Leaf             16.0       25.0          NaN
# 1                  V3    Leaf             16.0       25.0          NaN
# 2                  V3    Leaf             16.0       25.0          NaN
# 3                  V3    Leaf             16.0       25.0          NaN
# 4                  V3    Leaf             16.0       25.0          NaN
#
#    Relative humidity (%)  Light (umol/m2/s)  Growth Env. Media Notes
# 0                    NaN                NaN   Greenhouse   NaN   NaN
# 1                    NaN                NaN   Greenhouse   NaN   NaN
# 2                    NaN                NaN   Greenhouse   NaN   NaN
# 3                    NaN                NaN   Greenhouse   NaN   NaN
# 4                    NaN                NaN   Greenhouse   NaN   NaN
#
# [5 rows x 23 columns]

# %%
# reset index & merge with metadata
comtpm = vttpm_log.reset_index().rename(columns={"index":"Sample"})
mdcomtpm = comtpm.merge(md[["Sample","BioProject"]],how="inner",on="Sample")
mdcomtpm.set_index("Sample",inplace=True)

# %%
# generate a list of dataframes each with a single BioProject
dflist = []
for i in range(len(mdcomtpm["BioProject"].unique())):
    t = mdcomtpm["BioProject"].unique()[i]
    dflist.append(mdcomtpm[mdcomtpm["BioProject"]==t])
dflist[0].head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261         3.760627         1.731651         0.060075
# SRR11933272         4.109013         2.039269         0.490802
# SRR11933250         3.326079         1.994391         0.000000
# SRR11933029         3.201844         1.759475         0.000000
# SRR11933040         3.507319         1.925657         0.000000
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261         3.800400         2.644723         3.597631
# SRR11933272         3.038092         1.537277         1.742518
# SRR11933250         2.032962         1.842599         4.103174
# SRR11933029         1.447213         1.549133         4.364607
# SRR11933040         1.189432         2.254362         4.372791
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.494946              0.0         1.086039
# SRR11933272         0.226885              0.0         1.714098
# SRR11933250         0.000000              0.0         1.540259
# SRR11933029         0.000000              0.0         1.389265
# SRR11933040         0.193789              0.0         1.706813
#
#              Zm00001eb000140  ...  Zm00001eb442820  Zm00001eb442840  \
# Sample                        ...
# SRR11933261              0.0  ...         0.000000              0.0
# SRR11933272              0.0  ...         0.173611              0.0
# SRR11933250              0.0  ...         0.000000              0.0
# SRR11933029              0.0  ...         0.000000              0.0
# SRR11933040              0.0  ...         0.017435              0.0
#
#              Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# Sample
# SRR11933261              0.0              0.0         0.389017
# SRR11933272              0.0              0.0         2.945473
# SRR11933250              0.0              0.0         0.503415
# SRR11933029              0.0              0.0         0.000000
# SRR11933040              0.0              0.0         3.409421
#
#              Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  \
# Sample
# SRR11933261              0.0         0.000000              0.0
# SRR11933272              0.0         0.000000              0.0
# SRR11933250              0.0         0.326679              0.0
# SRR11933029              0.0         0.000000              0.0
# SRR11933040              0.0         0.000000              0.0
#
#              Zm00001eb443030   BioProject
# Sample
# SRR11933261         0.000000  PRJNA637522
# SRR11933272         0.000000  PRJNA637522
# SRR11933250         1.146231  PRJNA637522
# SRR11933029         1.244933  PRJNA637522
# SRR11933040         1.745435  PRJNA637522
#
# [5 rows x 38996 columns]

# %%
# for each dataframe in dflist: remove the columns not beginning with Zm, then transpose the dataframe
dl2 = []
for df in dflist:
    filtered_columns = [col for col in df.columns if col.startswith("Zm")]
    df2 = df[filtered_columns]
    dl2.append(df2.transpose())

# %%
# generate the batch variable for BioProject
batch = []
for j in range(len(dl2)):
    batch.extend([j for _ in range(len(dl2[j].columns))])

# %%
# go back to vttpm_log and re-transpose it
vtpm_log = vttpm_log.transpose()
vtpm_log.head()
# Out:
# Sample           SRR11933261  SRR11933272  SRR11933250  SRR11933029  \
# Zm00001eb000010     3.760627     4.109013     3.326079     3.201844
# Zm00001eb000020     1.731651     2.039269     1.994391     1.759475
# Zm00001eb000050     0.060075     0.490802     0.000000     0.000000
# Zm00001eb000060     3.800400     3.038092     2.032962     1.447213
# Zm00001eb000070     2.644723     1.537277     1.842599     1.549133
#
# Sample           SRR11933040  SRR11932822  SRR11932811  SRR11933230  \
# Zm00001eb000010     3.507319     5.264161     5.354941     4.985365
# Zm00001eb000020     1.925657     4.833336     4.550943     4.680800
# Zm00001eb000050     0.000000     0.000000     0.000000     0.000000
# Zm00001eb000060     1.189432     4.931234     4.532830     4.534223
# Zm00001eb000070     2.254362     3.001007     3.102715     2.649520
#
# Sample           SRR11932879  SRR11933475  ...  Ms71D3C    Ki3D1C  CML228D1D  \
# Zm00001eb000010     4.608395     4.019939  ...  1.27328  1.547709   1.279532
# Zm00001eb000020     3.103594     2.296733  ...  0.00000  1.485257   0.000000
# Zm00001eb000050     0.383775     0.416658  ...  0.00000  0.000000   0.000000
# Zm00001eb000060     3.975189     3.898004  ...  0.00000  0.000000   0.000000
# Zm00001eb000070     1.668005     1.491079  ...  0.00000  0.537870   0.000000
#
# Sample           CML333D3D  MO18WD3C   B73D3C  NC358D3C    P39D3D  M162WD3D  \
# Zm00001eb000010   3.403289  1.155814  1.98776  1.481069  2.402443  2.149165
# Zm00001eb000020   0.000000  1.548514  0.64318  0.234395  0.832973  0.464142
# Zm00001eb000050   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# Zm00001eb000060   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# Zm00001eb000070   1.013190  0.000000  0.00000  0.000000  0.000000  1.411628
#
# Sample           M162WD1D
# Zm00001eb000010  2.169362
# Zm00001eb000020  0.549750
# Zm00001eb000050  0.000000
# Zm00001eb000060  0.000000
# Zm00001eb000070  0.806190
#
# [5 rows x 1981 columns]

# %%
# run pyComBat for BioProject
bpcor_logtpm = pycombat(vtpm_log,batch)
# Out:
# Found 39 batches.
# Adjusting for 0 covariate(s) or covariate level(s).
# Standardizing Data across genes.
# Fitting L/S model and finding priors.
# Finding parametric adjustments.
# /home/leviathan22/.local/lib/python3.8/site-packages/combat/pycombat.py:159: RuntimeWarning: divide by zero encountered in divide
#   np.absolute(d_new-d_old)/d_old))  # maximum difference between new and old estimate
# Adjusting the Data

# %%
bplt = bpcor_logtpm.transpose().reset_index()
bplt.head()
# Out:
#         Sample  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR11933261         3.594095         2.519998        -0.007294
# 1  SRR11933272         3.894440         2.732825         0.381698
# 2  SRR11933250         3.219469         2.701776        -0.061548
# 3  SRR11933029         3.112365         2.539248        -0.061548
# 4  SRR11933040         3.375717         2.654222        -0.061548
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         3.905214         1.951832         3.598633         0.449177
# 1         3.249370         1.059086         1.839096         0.248810
# 2         2.384618         1.305216         4.078129         0.079220
# 3         1.880675         1.068644         4.326093         0.079220
# 4         1.658896         1.637151         4.333856         0.224072
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442810  Zm00001eb442820  \
# 0         0.114911         0.941737  ...         0.168084         0.628605
# 1         0.114911         1.555088  ...         0.110313         0.732666
# 2         0.114911         1.385320  ...         0.003340         0.628605
# 3         0.114911         1.237862  ...         0.003340         0.628605
# 4         0.114911         1.547974  ...         0.174403         0.639055
#
#    Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# 0        -0.003964         0.000153        -0.023113         0.303027
# 1        -0.003964         0.000153        -0.023113         3.022989
# 2        -0.003964         0.000153        -0.023113         0.424741
# 3        -0.003964         0.000153        -0.023113        -0.110871
# 4        -0.003964         0.000153        -0.023113         3.516611
#
#    Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0        -0.006205         0.060129        -0.003772        -0.020035
# 1        -0.006205         0.060129        -0.003772        -0.020035
# 2        -0.006205         0.332574        -0.003772         1.026435
# 3        -0.006205         0.060129        -0.003772         1.116546
# 4        -0.006205         0.060129        -0.003772         1.573487
#
# [5 rows x 38996 columns]

# %%
# save bplt
bplt.to_csv("./BioProject_corrected_logTPM_all.tsv",sep="\t",header=True,index=False)

# %% [markdown]
# New section: try running pyComBat before log transformation (but after variance thresholding). Does this make a difference in the PCA?

# %%
vttpm.reset_index().head()
# Out:
#         Sample  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR11933261        12.553818         2.321077         0.042520
# 1  SRR11933272        16.255838         3.110372         0.405226
# 2  SRR11933250         9.028815         2.984479         0.000000
# 3  SRR11933029         8.201340         2.385748         0.000000
# 4  SRR11933040        10.371251         2.799099         0.000000
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0        12.932676         5.253755        11.105837         0.409268
# 1         7.214039         1.902461         2.346186         0.170305
# 2         3.092442         2.586555        16.186141         0.000000
# 3         1.726808         1.926412        19.600487         0.000000
# 4         1.280629         3.771234        19.717683         0.143764
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442810  Zm00001eb442820  \
# 0              0.0         1.122904  ...         0.171184         0.000000
# 1              0.0         2.280915  ...         0.108052         0.127878
# 2              0.0         1.908468  ...         0.000000         0.000000
# 3              0.0         1.619452  ...         0.000000         0.000000
# 4              0.0         2.264390  ...         0.178304         0.012158
#
#    Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# 0              0.0              0.0              0.0         0.309501
# 1              0.0              0.0              0.0         6.703281
# 2              0.0              0.0              0.0         0.417565
# 3              0.0              0.0              0.0         0.000000
# 4              0.0              0.0              0.0         9.625225
#
#    Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0              0.0         0.000000              0.0         0.000000
# 1              0.0         0.000000              0.0         0.000000
# 2              0.0         0.254123              0.0         1.213349
# 3              0.0         0.000000              0.0         1.370075
# 4              0.0         0.000000              0.0         2.352959
#
# [5 rows x 38996 columns]

# %%
# reset index & merge with metadata
comtpm2 = vttpm.reset_index()
mdcomtpm2 = comtpm2.merge(md[["Sample","BioProject"]],how="inner",on="Sample")
mdcomtpm2.set_index("Sample",inplace=True)

# %%
# generate a list of dataframes each with a single BioProject
dflist = []
for i in range(len(mdcomtpm2["BioProject"].unique())):
    t = mdcomtpm2["BioProject"].unique()[i]
    dflist.append(mdcomtpm2[mdcomtpm2["BioProject"]==t])
dflist[0].head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261        12.553818         2.321077         0.042520
# SRR11933272        16.255838         3.110372         0.405226
# SRR11933250         9.028815         2.984479         0.000000
# SRR11933029         8.201340         2.385748         0.000000
# SRR11933040        10.371251         2.799099         0.000000
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261        12.932676         5.253755        11.105837
# SRR11933272         7.214039         1.902461         2.346186
# SRR11933250         3.092442         2.586555        16.186141
# SRR11933029         1.726808         1.926412        19.600487
# SRR11933040         1.280629         3.771234        19.717683
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.409268              0.0         1.122904
# SRR11933272         0.170305              0.0         2.280915
# SRR11933250         0.000000              0.0         1.908468
# SRR11933029         0.000000              0.0         1.619452
# SRR11933040         0.143764              0.0         2.264390
#
#              Zm00001eb000140  ...  Zm00001eb442820  Zm00001eb442840  \
# Sample                        ...
# SRR11933261              0.0  ...         0.000000              0.0
# SRR11933272              0.0  ...         0.127878              0.0
# SRR11933250              0.0  ...         0.000000              0.0
# SRR11933029              0.0  ...         0.000000              0.0
# SRR11933040              0.0  ...         0.012158              0.0
#
#              Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# Sample
# SRR11933261              0.0              0.0         0.309501
# SRR11933272              0.0              0.0         6.703281
# SRR11933250              0.0              0.0         0.417565
# SRR11933029              0.0              0.0         0.000000
# SRR11933040              0.0              0.0         9.625225
#
#              Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  \
# Sample
# SRR11933261              0.0         0.000000              0.0
# SRR11933272              0.0         0.000000              0.0
# SRR11933250              0.0         0.254123              0.0
# SRR11933029              0.0         0.000000              0.0
# SRR11933040              0.0         0.000000              0.0
#
#              Zm00001eb443030   BioProject
# Sample
# SRR11933261         0.000000  PRJNA637522
# SRR11933272         0.000000  PRJNA637522
# SRR11933250         1.213349  PRJNA637522
# SRR11933029         1.370075  PRJNA637522
# SRR11933040         2.352959  PRJNA637522
#
# [5 rows x 38996 columns]

# %%
# for each dataframe in dflist: remove the columns not beginning with Zm, then transpose the dataframe
dl2 = []
for df in dflist:
    filtered_columns = [col for col in df.columns if col.startswith("Zm")]
    df2 = df[filtered_columns]
    dl2.append(df2.transpose())

# %%
# generate the batch variable for BioProject
batch = []
for j in range(len(dl2)):
    batch.extend([j for _ in range(len(dl2[j].columns))])

# %%
# go back to vttpm and re-transpose it
vtpm = vttpm.transpose()
vtpm.head()
# Out:
# Sample           SRR11933261  SRR11933272  SRR11933250  SRR11933029  \
# Zm00001eb000010    12.553818    16.255838     9.028815     8.201340
# Zm00001eb000020     2.321077     3.110372     2.984479     2.385748
# Zm00001eb000050     0.042520     0.405226     0.000000     0.000000
# Zm00001eb000060    12.932676     7.214039     3.092442     1.726808
# Zm00001eb000070     5.253755     1.902461     2.586555     1.926412
#
# Sample           SRR11933040  SRR11932822  SRR11932811  SRR11933230  \
# Zm00001eb000010    10.371251    37.430009    39.925873    30.677016
# Zm00001eb000020     2.799099    27.508819    22.440680    24.648455
# Zm00001eb000050     0.000000     0.000000     0.000000     0.000000
# Zm00001eb000060     1.280629    29.510498    22.148225    22.170584
# Zm00001eb000070     3.771234     7.005587     7.590336     5.274585
#
# Sample           SRR11932879  SRR11933475  ...   Ms71D3C    Ki3D1C  CML228D1D  \
# Zm00001eb000010    23.393003    15.222661  ...  1.417104  1.923525   1.427602
# Zm00001eb000020     7.595576     3.913437  ...  0.000000  1.799671   0.000000
# Zm00001eb000050     0.304751     0.334832  ...  0.000000  0.000000   0.000000
# Zm00001eb000060    14.727189    13.907885  ...  0.000000  0.000000   0.000000
# Zm00001eb000070     2.177748     1.810991  ...  0.000000  0.451827   0.000000
#
# Sample           CML333D3D  MO18WD3C    B73D3C  NC358D3C    P39D3D  M162WD3D  \
# Zm00001eb000010   9.580153  1.228100  2.966207  1.791556  4.286976  3.435711
# Zm00001eb000020   0.000000  1.925157  0.561768  0.176413  0.781353  0.379497
# Zm00001eb000050   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Zm00001eb000060   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Zm00001eb000070   1.018369  0.000000  0.000000  0.000000  0.000000  1.660372
#
# Sample           M162WD1D
# Zm00001eb000010  3.498243
# Zm00001eb000020  0.463832
# Zm00001eb000050  0.000000
# Zm00001eb000060  0.000000
# Zm00001eb000070  0.748587
#
# [5 rows x 1981 columns]

# %%
# run pyComBat for BioProject
bpcor_tpm = pycombat(vtpm,batch)
# Out:
# Found 39 batches.
# Adjusting for 0 covariate(s) or covariate level(s).
# Standardizing Data across genes.
# Fitting L/S model and finding priors.
# Finding parametric adjustments.
# /home/leviathan22/.local/lib/python3.8/site-packages/combat/pycombat.py:159: RuntimeWarning: divide by zero encountered in divide
#   np.absolute(d_new-d_old)/d_old))  # maximum difference between new and old estimate
# Adjusting the Data

# %%
bpcor_tpm.head()
# Out:
# Sample           SRR11933261  SRR11933272  SRR11933250  SRR11933029  \
# Zm00001eb000010    11.893507    15.369406     8.583813     7.806881
# Zm00001eb000020    48.043564    48.466473    48.399019    48.078215
# Zm00001eb000050    -0.195001     0.297977    -0.252793    -0.252793
# Zm00001eb000060    17.979038    13.825805    10.832442     9.840633
# Zm00001eb000070     3.645409     0.855161     1.424730     0.875102
#
# Sample           SRR11933040  SRR11932822  SRR11932811  SRR11933230  \
# Zm00001eb000010     9.844253    35.250248    37.593663    28.909731
# Zm00001eb000020    48.299691    61.539335    58.823790    60.006732
# Zm00001eb000050    -0.252793    -0.252793    -0.252793    -0.252793
# Zm00001eb000060     9.516590    30.018893    24.671948    24.688187
# Zm00001eb000070     2.411080     5.103964     5.590819     3.662752
#
# Sample           SRR11932879  SRR11933475  ...    Ms71D3C     Ki3D1C  \
# Zm00001eb000010    22.070629    14.399336  ...   8.134132   8.654233
# Zm00001eb000020    50.869678    48.896761  ...  57.173127  58.173511
# Zm00001eb000050     0.161414     0.202300  ...   0.333643   0.333643
# Zm00001eb000060    19.282326    18.687296  ...  20.554886  20.554886
# Zm00001eb000070     1.084362     0.779004  ...   0.953879   2.558492
#
# Sample           CML228D1D  CML333D3D   MO18WD3C     B73D3C   NC358D3C  \
# Zm00001eb000010   8.144914  16.517693   7.940023   9.725082   8.518699
# Zm00001eb000020  57.173127  57.173127  58.243265  57.485397  57.271190
# Zm00001eb000050   0.333643   0.333643   0.333643   0.333643   0.333643
# Zm00001eb000060  20.554886  20.554886  20.554886  20.554886  20.554886
# Zm00001eb000070   0.953879   4.570502   0.953879   0.953879   0.953879
#
# Sample              P39D3D   M162WD3D   M162WD1D
# Zm00001eb000010  11.081529  10.207269  10.271490
# Zm00001eb000020  57.607458  57.384078  57.430957
# Zm00001eb000050   0.333643   0.333643   0.333643
# Zm00001eb000060  20.554886  20.554886  20.554886
# Zm00001eb000070   0.953879   6.850504   3.612402
#
# [5 rows x 1981 columns]

# %%
bpt = bpcor_tpm.transpose().reset_index()
bpt.head()
# Out:
#         Sample  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR11933261        11.893507        48.043564        -0.195001
# 1  SRR11933272        15.369406        48.466473         0.297977
# 2  SRR11933250         8.583813        48.399019        -0.252793
# 3  SRR11933029         7.806881        48.078215        -0.252793
# 4  SRR11933040         9.844253        48.299691        -0.252793
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0        17.979038         3.645409        19.803850         0.347005
# 1        13.825805         0.855161        12.780552         0.185579
# 2        10.832442         1.424730        23.877127         0.070533
# 3         9.840633         0.875102        26.614675         0.070533
# 4         9.516590         2.411080        26.708640         0.167649
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442810  Zm00001eb442820  \
# 0         0.034227         1.007776  ...         0.113725         1.592809
# 1         0.034227         2.347078  ...         0.074353         1.666817
# 2         0.034227         1.916323  ...         0.006965         1.592809
# 3         0.034227         1.582061  ...         0.006965         1.592809
# 4         0.034227         2.327966  ...         0.118166         1.599846
#
#    Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# 0        -0.003521          0.00006        -0.031864        -0.643666
# 1        -0.003521          0.00006        -0.031864         7.956798
# 2        -0.003521          0.00006        -0.031864        -0.498306
# 3        -0.003521          0.00006        -0.031864        -1.059985
# 4        -0.003521          0.00006        -0.031864        11.887192
#
#    Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0        -0.049156         0.083511        -0.003332        -0.005863
# 1        -0.049156         0.083511        -0.003332        -0.005863
# 2        -0.049156         0.241908        -0.003332         1.133667
# 3        -0.049156         0.083511        -0.003332         1.280858
# 4        -0.049156         0.083511        -0.003332         2.203945
#
# [5 rows x 38996 columns]

# %%
# save bpt, just in case
bpt.to_csv("./BioProject_corrected_rawTPM_all.tsv",sep="\t",header=True,index=False)

# %%
# run the PCA for both datasets
## re-load bplt
bplt = pd.read_csv("./BioProject_corrected_logTPM_all.tsv",sep="\t",header="infer")

# %%
# log transform bpt
bpt = bpt.set_index("Sample")
bpt_log = bpt.apply(lambda x: np.log2(x+1))
# Out:
# /home/leviathan22/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
bpt.head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261        11.893507        48.043564        -0.195001
# SRR11933272        15.369406        48.466473         0.297977
# SRR11933250         8.583813        48.399019        -0.252793
# SRR11933029         7.806881        48.078215        -0.252793
# SRR11933040         9.844253        48.299691        -0.252793
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261        17.979038         3.645409        19.803850
# SRR11933272        13.825805         0.855161        12.780552
# SRR11933250        10.832442         1.424730        23.877127
# SRR11933029         9.840633         0.875102        26.614675
# SRR11933040         9.516590         2.411080        26.708640
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.347005         0.034227         1.007776
# SRR11933272         0.185579         0.034227         2.347078
# SRR11933250         0.070533         0.034227         1.916323
# SRR11933029         0.070533         0.034227         1.582061
# SRR11933040         0.167649         0.034227         2.327966
#
#              Zm00001eb000140  ...  Zm00001eb442810  Zm00001eb442820  \
# Sample                        ...
# SRR11933261        -0.011901  ...         0.113725         1.592809
# SRR11933272        -0.011901  ...         0.074353         1.666817
# SRR11933250        -0.011901  ...         0.006965         1.592809
# SRR11933029        -0.011901  ...         0.006965         1.592809
# SRR11933040        -0.011901  ...         0.118166         1.599846
#
#              Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  \
# Sample
# SRR11933261        -0.003521          0.00006        -0.031864
# SRR11933272        -0.003521          0.00006        -0.031864
# SRR11933250        -0.003521          0.00006        -0.031864
# SRR11933029        -0.003521          0.00006        -0.031864
# SRR11933040        -0.003521          0.00006        -0.031864
#
#              Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# Sample
# SRR11933261        -0.643666        -0.049156         0.083511
# SRR11933272         7.956798        -0.049156         0.083511
# SRR11933250        -0.498306        -0.049156         0.241908
# SRR11933029        -1.059985        -0.049156         0.083511
# SRR11933040        11.887192        -0.049156         0.083511
#
#              Zm00001eb442980  Zm00001eb443030
# Sample
# SRR11933261        -0.003332        -0.005863
# SRR11933272        -0.003332        -0.005863
# SRR11933250        -0.003332         1.133667
# SRR11933029        -0.003332         1.280858
# SRR11933040        -0.003332         2.203945
#
# [5 rows x 38995 columns]

# %%
bpt_log.head()
# Out:
#              Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# Sample
# SRR11933261         3.688573         5.615992        -0.312941
# SRR11933272         4.032930         5.628379         0.376264
# SRR11933250         3.260600         5.626410        -0.420420
# SRR11933029         3.138631         5.617011        -0.420420
# SRR11933040         3.438859         5.623507        -0.420420
#
#              Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# Sample
# SRR11933261         4.246335         2.215806         4.378779
# SRR11933272         3.890039         0.891544         3.784562
# SRR11933250         3.564676         1.277824         4.636748
# SRR11933029         3.438377         0.906969         4.787363
# SRR11933040         3.394595         1.770228         4.792264
#
#              Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# Sample
# SRR11933261         0.429755         0.048553         1.005599
# SRR11933272         0.245591         0.048553         1.742902
# SRR11933250         0.098329         0.048553         1.544151
# SRR11933029         0.098329         0.048553         1.368523
# SRR11933040         0.223607         0.048553         1.734641
#
#              Zm00001eb000140  ...  Zm00001eb442810  Zm00001eb442820  \
# Sample                        ...
# SRR11933261        -0.017273  ...         0.155393         1.374516
# SRR11933272        -0.017273  ...         0.103468         1.415119
# SRR11933250        -0.017273  ...         0.010014         1.374516
# SRR11933029        -0.017273  ...         0.010014         1.374516
# SRR11933040        -0.017273  ...         0.161134         1.378426
#
#              Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  \
# Sample
# SRR11933261        -0.005088         0.000087        -0.046719
# SRR11933272        -0.005088         0.000087        -0.046719
# SRR11933250        -0.005088         0.000087        -0.046719
# SRR11933029        -0.005088         0.000087        -0.046719
# SRR11933040        -0.005088         0.000087        -0.046719
#
#              Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# Sample
# SRR11933261        -1.488698        -0.072719         0.115713
# SRR11933272         3.162983        -0.072719         0.115713
# SRR11933250        -0.995120        -0.072719         0.312558
# SRR11933029              NaN        -0.072719         0.115713
# SRR11933040         3.687866        -0.072719         0.115713
#
#              Zm00001eb442980  Zm00001eb443030
# Sample
# SRR11933261        -0.004815        -0.008484
# SRR11933272        -0.004815        -0.008484
# SRR11933250        -0.004815         1.093335
# SRR11933029        -0.004815         1.189577
# SRR11933040        -0.004815         1.679849
#
# [5 rows x 38995 columns]

# %%
# run PCA for bpt_log
pca=PCA(n_components=2)
real_PCs = pca.fit_transform(bpt_log)
real_PCs_df = pd.DataFrame(data = real_PCs, columns = ['PC1','PC2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 # run PCA for bpt_log
#       2 pca=PCA(n_components=2)
# ----> 3 real_PCs = pca.fit_transform(bpt_log)
#       4 real_PCs_df = pd.DataFrame(data = real_PCs, columns = ['PC1','PC2'])
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:462, in PCA.fit_transform(self, X, y)
#     439 """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441 Parameters
#    (...)
#     458 C-ordered array, use 'np.ascontiguousarray'.
#     459 """
#     460 self._validate_params()
# --> 462 U, S, Vt = self._fit(X)
#     463 U = U[:, : self.n_components_]
#     465 if self.whiten:
#     466     # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:485, in PCA._fit(self, X)
#     479 if issparse(X):
#     480     raise TypeError(
#     481         "PCA does not support sparse input. See "
#     482         "TruncatedSVD for a possible alternative."
#     483     )
# --> 485 X = self._validate_data(
#     486     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487 )
#     489 # Handle n_components==None
#     490 if self.n_components is None:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:546, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     544     raise ValueError("Validation should be done on X, y or both.")
#     545 elif not no_val_X and no_val_y:
# --> 546     X = check_array(X, input_name="X", **check_params)
#     547     out = X
#     548 elif no_val_X and not no_val_y:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# Moral of story: Use `bplt` instead of `bpt` - the latter has negative values some of which introduce NaNs when log transformed.

# %%
# add treatment & BioProject cols to bplt to make it ready for RF input
bplt_md = bplt.merge(md[["Sample","BioProject","Treatment"]])
bplt_md.head()
# Out:
#         Sample  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR11933261         3.594095         2.519998        -0.007294
# 1  SRR11933272         3.894440         2.732825         0.381698
# 2  SRR11933250         3.219469         2.701776        -0.061548
# 3  SRR11933029         3.112365         2.539248        -0.061548
# 4  SRR11933040         3.375717         2.654222        -0.061548
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         3.905214         1.951832         3.598633         0.449177
# 1         3.249370         1.059086         1.839096         0.248810
# 2         2.384618         1.305216         4.078129         0.079220
# 3         1.880675         1.068644         4.326093         0.079220
# 4         1.658896         1.637151         4.333856         0.224072
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442840  Zm00001eb442850  \
# 0         0.114911         0.941737  ...        -0.003964         0.000153
# 1         0.114911         1.555088  ...        -0.003964         0.000153
# 2         0.114911         1.385320  ...        -0.003964         0.000153
# 3         0.114911         1.237862  ...        -0.003964         0.000153
# 4         0.114911         1.547974  ...        -0.003964         0.000153
#
#    Zm00001eb442870  Zm00001eb442890  Zm00001eb442910  Zm00001eb442960  \
# 0        -0.023113         0.303027        -0.006205         0.060129
# 1        -0.023113         3.022989        -0.006205         0.060129
# 2        -0.023113         0.424741        -0.006205         0.332574
# 3        -0.023113        -0.110871        -0.006205         0.060129
# 4        -0.023113         3.516611        -0.006205         0.060129
#
#    Zm00001eb442980  Zm00001eb443030   BioProject  Treatment
# 0        -0.003772        -0.020035  PRJNA637522    Drought
# 1        -0.003772        -0.020035  PRJNA637522    Drought
# 2        -0.003772         1.026435  PRJNA637522    Drought
# 3        -0.003772         1.116546  PRJNA637522    Control
# 4        -0.003772         1.573487  PRJNA637522    Drought
#
# [5 rows x 38998 columns]

# %%
# save updated dataframe
bplt_md.to_csv("../../data/BPcombat_logTPM_forRF_1-Mar-2024.tsv",sep="\t",header=True,index=False)

# %%
# check that the photosynthetic tissues data are correctly set up as well
psyn = pd.read_csv("../../data/psyn_tissues_tpm_combatBioProject.tsv",sep="\t",header="infer")
psyn.head()
# Out:
#         Sample  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR11933261         3.676968         1.425305         0.019366
# 1  SRR11933272         4.041835         1.692175         0.546391
# 2  SRR11933250         3.221863         1.653241        -0.054140
# 3  SRR11933029         3.091750         1.449443        -0.054140
# 4  SRR11933040         3.411677         1.593612        -0.054140
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         3.454238         2.464770         3.181359         0.480547
# 1         2.778114         1.452964         1.410374         0.260699
# 2         1.886622         1.731918         3.663976         0.074623
# 3         1.367097         1.463797         3.913553         0.074623
# 4         1.138459         2.108122         3.921366         0.233557
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442810  Zm00001eb442820  \
# 0        -0.043836         1.148040  ...         0.197235        -0.007364
# 1        -0.043836         1.765632  ...         0.130296         0.118151
# 2        -0.043836         1.594690  ...         0.006349        -0.007364
# 3        -0.043836         1.446212  ...         0.006349        -0.007364
# 4        -0.043836         1.758469  ...         0.204556         0.005240
#
#    Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442890  \
# 0         0.004322        -0.000069        -0.025771         0.197944
# 1         0.004322        -0.000069        -0.025771         2.373048
# 2         0.004322        -0.000069        -0.025771         0.295277
# 3         0.004322        -0.000069        -0.025771        -0.133042
# 4         0.004322        -0.000069        -0.025771         2.767788
#
#    Zm00001eb442910  Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0        -0.006917         0.030309        -0.000506         0.127112
# 1        -0.006917         0.030309        -0.000506         0.127112
# 2        -0.006917         0.303918        -0.000506         1.162604
# 3        -0.006917         0.030309        -0.000506         1.251770
# 4        -0.006917         0.030309        -0.000506         1.703918
#
# [5 rows x 38931 columns]

# %%
psyn = psyn.merge(md[["Sample","Treatment","BioProject"]])

# %%
psyn.to_csv("../../data/BPcombat_logTPM_psyn_tissues_forRF_1-Mar-2024.tsv",sep="\t",header=True,index=False)
