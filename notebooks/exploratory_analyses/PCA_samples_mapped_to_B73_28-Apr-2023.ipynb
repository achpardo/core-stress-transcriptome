# %% [markdown]
# Purpose: Run PCA of TPM for the following samples mapped to B73: all B73, all Mo17, all W22, all CML69, all Oh43 (>500 samples total).<br>
# Author: Anna Pardo<br>
# Date initiated: April 28, 2023

# %%
# load modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold

# %%
# load TPM matrix
## this TPM was generated by running tximport on all the samples described above
tpm = pd.read_csv("TPM_LS_mapB73_nf-core_27-Apr-2023.txt",sep="\t",header="infer",index_col="GeneID")
tpm.head()
# Out:
#                  SRR8857799  SRR8857793  SRR15241108  SRR15241156  SRR8857749  \
# GeneID
# Zm00001eb000010    8.477884    1.349336    15.116249    13.781893    4.872421
# Zm00001eb000020  102.011193   39.493900     0.808690     0.565147   13.808307
# Zm00001eb000050    0.492838    0.000000     0.000000     0.000000    0.519128
# Zm00001eb000060   28.480082    7.311609    35.563727    18.684174    7.134804
# Zm00001eb000070    0.000000    0.000000     0.000000     0.000000    0.000000
#
#                  SRR8857746  SRR15241170  SRR8857844  SRR9282931  SRR2106196  \
# GeneID
# Zm00001eb000010   32.421567    13.266106   10.918767    1.099232    5.291619
# Zm00001eb000020    1.344191     1.035099  124.754873   45.137300   18.872878
# Zm00001eb000050    2.733165     0.000000    1.152023    0.000000    0.000000
# Zm00001eb000060   28.603220    22.302009   34.742011    2.411356    4.794730
# Zm00001eb000070    0.000000     0.000000    0.000000    0.000000    1.360438
#
#                  ...  SRR15241292  SRR15241281  SRR15241321  SRR12214348  \
# GeneID           ...
# Zm00001eb000010  ...    12.355163    21.049118     9.535489    12.052756
# Zm00001eb000020  ...     0.184505     0.458082     0.255254     1.053906
# Zm00001eb000050  ...     0.000000     0.000000     0.000000     0.000000
# Zm00001eb000060  ...    15.936412    19.830817    14.213556    19.629279
# Zm00001eb000070  ...     0.000000     0.000000     0.000000     0.000000
#
#                  SRR15241327  SRR12214377  SRR15241326  SRR12214374  \
# GeneID
# Zm00001eb000010    10.945717    11.219040     8.066795    15.008765
# Zm00001eb000020     0.456107     1.822988     0.237454     1.641823
# Zm00001eb000050     0.000000     0.000000     0.000000     0.000000
# Zm00001eb000060    12.166175    18.421093     9.438759    25.698837
# Zm00001eb000070     0.000000     0.226282     0.000000     0.000000
#
#                  SRR12214352  SRR15241319
# GeneID
# Zm00001eb000010     9.932600    13.488960
# Zm00001eb000020     1.577966     0.432152
# Zm00001eb000050     0.000000     0.000000
# Zm00001eb000060    20.623343    17.958151
# Zm00001eb000070     0.000000     0.115324
#
# [5 rows x 515 columns]

# %%
# define a function from an answer in https://stackoverflow.com/questions/39812885/retain-feature-names-after-scikit-feature-selection
def variance_threshold_selector(data):
    selector = VarianceThreshold()
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
# transpose TPM data
ttpm = tpm.transpose()
ttpm.head()
# Out:
# GeneID       Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# SRR8857799          8.477884       102.011193         0.492838
# SRR8857793          1.349336        39.493900         0.000000
# SRR15241108        15.116249         0.808690         0.000000
# SRR15241156        13.781893         0.565147         0.000000
# SRR8857749          4.872421        13.808307         0.519128
#
# GeneID       Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# SRR8857799         28.480082              0.0        25.786615
# SRR8857793          7.311609              0.0        14.504660
# SRR15241108        35.563727              0.0        10.080573
# SRR15241156        18.684174              0.0         9.818174
# SRR8857749          7.134804              0.0         4.857101
#
# GeneID       Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# SRR8857799          0.390458              0.0         1.041538
# SRR8857793          1.032018              0.0         0.000000
# SRR15241108         0.000000              0.0         0.288952
# SRR15241156         0.000000              0.0         0.000000
# SRR8857749          0.094921              0.0         0.381624
#
# GeneID       Zm00001eb000140  ...  Zm00001eb442840  Zm00001eb442850  \
# SRR8857799               0.0  ...              0.0              0.0
# SRR8857793               0.0  ...              0.0              0.0
# SRR15241108              0.0  ...              0.0              0.0
# SRR15241156              0.0  ...              0.0              0.0
# SRR8857749               0.0  ...              0.0              0.0
#
# GeneID       Zm00001eb442870  Zm00001eb442880  Zm00001eb442890  \
# SRR8857799          0.000000              0.0              0.0
# SRR8857793          0.000000              0.0              0.0
# SRR15241108         0.000000              0.0              0.0
# SRR15241156         0.228073              0.0              0.0
# SRR8857749          0.000000              0.0              0.0
#
# GeneID       Zm00001eb442910  Zm00001eb442940  Zm00001eb442960  \
# SRR8857799               0.0         0.267260              0.0
# SRR8857793               0.0         5.135086              0.0
# SRR15241108              0.0         0.480562              0.0
# SRR15241156              0.0         0.413354              0.0
# SRR8857749               0.0         1.021196              0.0
#
# GeneID       Zm00001eb442980  Zm00001eb443030
# SRR8857799               0.0         0.000000
# SRR8857793               0.0         0.000000
# SRR15241108              0.0         0.000000
# SRR15241156              0.0         0.880361
# SRR8857749               0.0         0.000000
#
# [5 rows x 39092 columns]

# %%
# put through VarianceThreshold() using the variance_threshold_selector() defined above
vttpm = variance_threshold_selector(ttpm)
vttpm.head()
# Out:
# GeneID       Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# SRR8857799          8.477884       102.011193         0.492838
# SRR8857793          1.349336        39.493900         0.000000
# SRR15241108        15.116249         0.808690         0.000000
# SRR15241156        13.781893         0.565147         0.000000
# SRR8857749          4.872421        13.808307         0.519128
#
# GeneID       Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# SRR8857799         28.480082              0.0        25.786615
# SRR8857793          7.311609              0.0        14.504660
# SRR15241108        35.563727              0.0        10.080573
# SRR15241156        18.684174              0.0         9.818174
# SRR8857749          7.134804              0.0         4.857101
#
# GeneID       Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# SRR8857799          0.390458              0.0         1.041538
# SRR8857793          1.032018              0.0         0.000000
# SRR15241108         0.000000              0.0         0.288952
# SRR15241156         0.000000              0.0         0.000000
# SRR8857749          0.094921              0.0         0.381624
#
# GeneID       Zm00001eb000140  ...  Zm00001eb442830  Zm00001eb442840  \
# SRR8857799               0.0  ...              0.0              0.0
# SRR8857793               0.0  ...              0.0              0.0
# SRR15241108              0.0  ...              0.0              0.0
# SRR15241156              0.0  ...              0.0              0.0
# SRR8857749               0.0  ...              0.0              0.0
#
# GeneID       Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# SRR8857799               0.0         0.000000              0.0
# SRR8857793               0.0         0.000000              0.0
# SRR15241108              0.0         0.000000              0.0
# SRR15241156              0.0         0.228073              0.0
# SRR8857749               0.0         0.000000              0.0
#
# GeneID       Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  \
# SRR8857799               0.0         0.267260              0.0
# SRR8857793               0.0         5.135086              0.0
# SRR15241108              0.0         0.480562              0.0
# SRR15241156              0.0         0.413354              0.0
# SRR8857749               0.0         1.021196              0.0
#
# GeneID       Zm00001eb442980  Zm00001eb443030
# SRR8857799               0.0         0.000000
# SRR8857793               0.0         0.000000
# SRR15241108              0.0         0.000000
# SRR15241156              0.0         0.880361
# SRR8857749               0.0         0.000000
#
# [5 rows x 38901 columns]

# %%
len(ttpm.columns)
# Out:
# 39092

# %%
len(vttpm.columns)
# Out:
# 38901

# %% [markdown]
# Running `VarianceThreshold()` eliminated 191 low-variance genes.

# %%
vttpm_log = vttpm.apply(lambda x: np.log2(x+1))
vttpm_log.head()
# Out:
# GeneID       Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# SRR8857799          3.244565         6.686657         0.578058
# SRR8857793          1.232253         5.339633         0.000000
# SRR15241108         4.010444         0.854945         0.000000
# SRR15241156         3.885759         0.646298         0.000000
# SRR8857749          2.553955         3.888335         0.603243
#
# GeneID       Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# SRR8857799          4.881669              0.0         4.743440
# SRR8857793          3.055128              0.0         3.954630
# SRR15241108         5.192341              0.0         3.469961
# SRR15241156         4.298964              0.0         3.435385
# SRR8857749          3.024108              0.0         2.550187
#
# GeneID       Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# SRR8857799          0.475560              0.0         1.029656
# SRR8857793          1.022913              0.0         0.000000
# SRR15241108         0.000000              0.0         0.366199
# SRR15241156         0.000000              0.0         0.000000
# SRR8857749          0.130827              0.0         0.466365
#
# GeneID       Zm00001eb000140  ...  Zm00001eb442830  Zm00001eb442840  \
# SRR8857799               0.0  ...              0.0              0.0
# SRR8857793               0.0  ...              0.0              0.0
# SRR15241108              0.0  ...              0.0              0.0
# SRR15241156              0.0  ...              0.0              0.0
# SRR8857749               0.0  ...              0.0              0.0
#
# GeneID       Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# SRR8857799               0.0         0.000000              0.0
# SRR8857793               0.0         0.000000              0.0
# SRR15241108              0.0         0.000000              0.0
# SRR15241156              0.0         0.296396              0.0
# SRR8857749               0.0         0.000000              0.0
#
# GeneID       Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  \
# SRR8857799               0.0         0.341713              0.0
# SRR8857793               0.0         2.617084              0.0
# SRR15241108              0.0         0.566145              0.0
# SRR15241156              0.0         0.499123              0.0
# SRR8857749               0.0         1.015209              0.0
#
# GeneID       Zm00001eb442980  Zm00001eb443030
# SRR8857799               0.0          0.00000
# SRR8857793               0.0          0.00000
# SRR15241108              0.0          0.00000
# SRR15241156              0.0          0.91101
# SRR8857749               0.0          0.00000
#
# [5 rows x 38901 columns]

# %%
pca = PCA(n_components=2)
real_PCs = pca.fit_transform(vttpm_log)
real_PCs_df = pd.DataFrame(data = real_PCs, columns = ['PC1','PC2'])

# %%
real_PCs_df
# Out:
#             PC1         PC2
# 0    181.697368  -59.165437
# 1    202.819544   -5.185001
# 2   -117.462444  -45.852541
# 3   -116.278547  -30.209548
# 4      5.781672  105.115463
# ..          ...         ...
# 510  -96.795902  -47.148634
# 511 -148.443860   -4.285952
# 512  -87.086260  -64.103429
# 513 -143.477935  -10.402167
# 514 -145.338291  -29.258775
#
# [515 rows x 2 columns]

# %%
# find the explained variance ratio
pca.explained_variance_ratio_
# Out:
# array([0.28708135, 0.16617365])

# %%
## reset index (after running PCA)
vttpm_log.reset_index(inplace=True)
vttpm_log.head()
# Out:
# GeneID        index  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0        SRR8857799         3.244565         6.686657         0.578058
# 1        SRR8857793         1.232253         5.339633         0.000000
# 2       SRR15241108         4.010444         0.854945         0.000000
# 3       SRR15241156         3.885759         0.646298         0.000000
# 4        SRR8857749         2.553955         3.888335         0.603243
#
# GeneID  Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0              4.881669              0.0         4.743440         0.475560
# 1              3.055128              0.0         3.954630         1.022913
# 2              5.192341              0.0         3.469961         0.000000
# 3              4.298964              0.0         3.435385         0.000000
# 4              3.024108              0.0         2.550187         0.130827
#
# GeneID  Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442830  \
# 0                   0.0         1.029656  ...              0.0
# 1                   0.0         0.000000  ...              0.0
# 2                   0.0         0.366199  ...              0.0
# 3                   0.0         0.000000  ...              0.0
# 4                   0.0         0.466365  ...              0.0
#
# GeneID  Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# 0                   0.0              0.0         0.000000              0.0
# 1                   0.0              0.0         0.000000              0.0
# 2                   0.0              0.0         0.000000              0.0
# 3                   0.0              0.0         0.296396              0.0
# 4                   0.0              0.0         0.000000              0.0
#
# GeneID  Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  \
# 0                   0.0         0.341713              0.0              0.0
# 1                   0.0         2.617084              0.0              0.0
# 2                   0.0         0.566145              0.0              0.0
# 3                   0.0         0.499123              0.0              0.0
# 4                   0.0         1.015209              0.0              0.0
#
# GeneID  Zm00001eb443030
# 0               0.00000
# 1               0.00000
# 2               0.00000
# 3               0.91101
# 4               0.00000
#
# [5 rows x 38902 columns]

# %%
# load metadata
md = pd.read_csv("srr_numbers_with_metadata_14-Apr-2023.tsv",sep="\t",header="infer")
md.head()
# Out:
#     BioProject   SRA_number sample_name  Replicate_num Genotype  \
# 0  PRJNA637522  SRR11933261     238_WS2            NaN      238
# 1  PRJNA637522  SRR11933272     238_WS1            NaN      238
# 2  PRJNA637522  SRR11933250     268_WS1            NaN      268
# 3  PRJNA637522  SRR11933029      268_WW            NaN      268
# 4  PRJNA637522  SRR11933040     268_WS2            NaN      268
#
#             Technology Library_layout Treatment  Duration_hours  \
# 0  Illumina HiSeq 2500         PAIRED   Drought           312.0
# 1  Illumina HiSeq 2500         PAIRED   Drought           216.0
# 2  Illumina HiSeq 2500         PAIRED   Drought           216.0
# 3  Illumina HiSeq 2500         PAIRED   Control           216.0
# 4  Illumina HiSeq 2500         PAIRED   Drought           312.0
#
#   Time_after_treatment  ...  Developmental_stage Tissue Day_length_hours  \
# 0              13 days  ...                   V3   Leaf             16.0
# 1               9 days  ...                   V3   Leaf             16.0
# 2               9 days  ...                   V3   Leaf             16.0
# 3               9 days  ...                   V3   Leaf             16.0
# 4              13 days  ...                   V3   Leaf             16.0
#
#   Day_temp_C  Night_temp_C  Relative humidity (%)  Light (umol/m2/s)  \
# 0       25.0           NaN                    NaN                NaN
# 1       25.0           NaN                    NaN                NaN
# 2       25.0           NaN                    NaN                NaN
# 3       25.0           NaN                    NaN                NaN
# 4       25.0           NaN                    NaN                NaN
#
#   Growth Env. Media Notes
# 0  Greenhouse   NaN   NaN
# 1  Greenhouse   NaN   NaN
# 2  Greenhouse   NaN   NaN
# 3  Greenhouse   NaN   NaN
# 4  Greenhouse   NaN   NaN
#
# [5 rows x 22 columns]

# %%
# in vttpm_log, rename column "index" to "SRA_number"
vttpm_log.rename(columns={"index":"SRA_number"},inplace=True)
vttpm_log.head()
# Out:
# GeneID   SRA_number  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0        SRR8857799         3.244565         6.686657         0.578058
# 1        SRR8857793         1.232253         5.339633         0.000000
# 2       SRR15241108         4.010444         0.854945         0.000000
# 3       SRR15241156         3.885759         0.646298         0.000000
# 4        SRR8857749         2.553955         3.888335         0.603243
#
# GeneID  Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0              4.881669              0.0         4.743440         0.475560
# 1              3.055128              0.0         3.954630         1.022913
# 2              5.192341              0.0         3.469961         0.000000
# 3              4.298964              0.0         3.435385         0.000000
# 4              3.024108              0.0         2.550187         0.130827
#
# GeneID  Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442830  \
# 0                   0.0         1.029656  ...              0.0
# 1                   0.0         0.000000  ...              0.0
# 2                   0.0         0.366199  ...              0.0
# 3                   0.0         0.000000  ...              0.0
# 4                   0.0         0.466365  ...              0.0
#
# GeneID  Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# 0                   0.0              0.0         0.000000              0.0
# 1                   0.0              0.0         0.000000              0.0
# 2                   0.0              0.0         0.000000              0.0
# 3                   0.0              0.0         0.296396              0.0
# 4                   0.0              0.0         0.000000              0.0
#
# GeneID  Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  \
# 0                   0.0         0.341713              0.0              0.0
# 1                   0.0         2.617084              0.0              0.0
# 2                   0.0         0.566145              0.0              0.0
# 3                   0.0         0.499123              0.0              0.0
# 4                   0.0         1.015209              0.0              0.0
#
# GeneID  Zm00001eb443030
# 0               0.00000
# 1               0.00000
# 2               0.00000
# 3               0.91101
# 4               0.00000
#
# [5 rows x 38902 columns]

# %%
# merge with metadata
## note this has to maintain the sample order of vttpm_log, otherwise when we concatenate it with the PC df everything will be
## incorrectly matched up
vttpm_log_merged = vttpm_log.merge(md,how="inner")
vttpm_log_merged.head()
# Out:
#     SRA_number  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0   SRR8857799         3.244565         6.686657         0.578058
# 1   SRR8857793         1.232253         5.339633         0.000000
# 2  SRR15241108         4.010444         0.854945         0.000000
# 3  SRR15241156         3.885759         0.646298         0.000000
# 4   SRR8857749         2.553955         3.888335         0.603243
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         4.881669              0.0         4.743440         0.475560
# 1         3.055128              0.0         3.954630         1.022913
# 2         5.192341              0.0         3.469961         0.000000
# 3         4.298964              0.0         3.435385         0.000000
# 4         3.024108              0.0         2.550187         0.130827
#
#    Zm00001eb000110  Zm00001eb000120  ...  Developmental_stage  Tissue  \
# 0              0.0         1.029656  ...                   V3   Stalk
# 1              0.0         0.000000  ...                   V3    Root
# 2              0.0         0.366199  ...                V2/V3    Leaf
# 3              0.0         0.000000  ...                V2/V3    Leaf
# 4              0.0         0.466365  ...                   R1  Tassel
#
#    Day_length_hours  Day_temp_C  Night_temp_C  Relative humidity (%)  \
# 0              14.0        38.0           NaN                     65
# 1              14.0        25.0           NaN                     65
# 2              16.0        30.0          20.0                    NaN
# 3              16.0        39.0          29.0                    NaN
# 4              14.0        38.0           NaN                     65
#
#    Light (umol/m2/s)  Growth Env.  Media  Notes
# 0                NaN    Phytotron    NaN    NaN
# 1                NaN    Phytotron    NaN    NaN
# 2                NaN          NaN    NaN    NaN
# 3                NaN          NaN    NaN    NaN
# 4                NaN    Phytotron    NaN    NaN
#
# [5 rows x 38923 columns]

# %%
for i in list(vttpm_log_merged.columns):
    if not i.startswith("Zm"):
        print(i)
# Out:
# SRA_number
# BioProject
# sample_name
# Replicate_num
# Genotype
# Technology
# Library_layout
# Treatment
# Duration_hours
# Time_after_treatment
# Concentration_mM
# Concentration
# Developmental_stage
# Tissue
# Day_length_hours
# Day_temp_C
# Night_temp_C
# Relative humidity (%)
# Light (umol/m2/s)
# Growth Env.
# Media
# Notes

# %%
# append metadata to PCA df
plotdf = pd.concat([real_PCs_df,vttpm_log_merged[["BioProject","Genotype","Treatment","Time_after_treatment","Concentration",
                                                 "Developmental_stage","Tissue","Day_length_hours","Day_temp_C","Night_temp_C",
                                                 "Relative humidity (%)","Light (umol/m2/s)","Growth Env.","Media"]]],axis=1)
plotdf.head()
# Out:
#           PC1         PC2   BioProject Genotype Treatment  \
# 0  181.697368  -59.165437  PRJNA520822      B73      Heat
# 1  202.819544   -5.185001  PRJNA520822      B73   Control
# 2 -117.462444  -45.852541  PRJNA747925      B73   Control
# 3 -116.278547  -30.209548  PRJNA747925      B73      Heat
# 4    5.781672  105.115463  PRJNA520822      B73      Heat
#
#   Time_after_treatment Concentration Developmental_stage  Tissue  \
# 0              2 hours           NaN                  V3   Stalk
# 1               0 hour           NaN                  V3    Root
# 2             25 hours           NaN               V2/V3    Leaf
# 3               1 hour           NaN               V2/V3    Leaf
# 4              2 hours           NaN                  R1  Tassel
#
#    Day_length_hours  Day_temp_C  Night_temp_C Relative humidity (%)  \
# 0              14.0        38.0           NaN                    65
# 1              14.0        25.0           NaN                    65
# 2              16.0        30.0          20.0                   NaN
# 3              16.0        39.0          29.0                   NaN
# 4              14.0        38.0           NaN                    65
#
#   Light (umol/m2/s) Growth Env. Media
# 0               NaN   Phytotron   NaN
# 1               NaN   Phytotron   NaN
# 2               NaN         NaN   NaN
# 3               NaN         NaN   NaN
# 4               NaN   Phytotron   NaN

# %%
# make subplots & color by different things: BioProject, treatment, day temperature, dev stage, growth env, tissue, 
## genotype

fig,ax = plt.subplots(nrows=4,ncols=2,figsize = (15,20))

a = sns.scatterplot(ax=ax[0,0],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["BioProject"],palette="tab20",s=75,alpha=0.75)
a.set_title("By BioProject",fontsize=12)
a.legend(bbox_to_anchor=(-0.13,1.1))
b = sns.scatterplot(ax=ax[0,1],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Treatment"],palette="tab20",s=75,alpha=0.75)
b.set_title("By Treatment",fontsize=12)
b.legend(bbox_to_anchor=(1.02,1.1))
sns.scatterplot(ax=ax[1,0],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Genotype"],palette="tab10",s=75,alpha=0.75).set_title("By Genotype",fontsize=12)
d = sns.scatterplot(ax=ax[1,1],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Developmental_stage"],palette="tab20",s=75,alpha=0.75)
d.set_title("By Dev. Stage",fontsize=12)
d.legend(bbox_to_anchor=(1.02,1.1))
e = sns.scatterplot(ax=ax[2,0],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Tissue"],palette="tab10",s=75,alpha=0.75)
e.set_title("By Tissue",fontsize=12)
e.legend(bbox_to_anchor=(-0.13,1))
sns.scatterplot(ax=ax[2,1],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Day_temp_C"],palette="magma",s=75,alpha=0.75).set_title("By Day Temperature",fontsize=12)
sns.scatterplot(ax=ax[3,0],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Growth Env."],palette="tab10",s=75,alpha=0.75).set_title("By Environment",fontsize=12)
sns.scatterplot(ax=ax[3,1],x=plotdf["PC1"],y=plotdf["PC2"],hue=plotdf["Media"],palette="tab10",s=75,alpha=0.75).set_title("By Growth Media",fontsize=12)

plt.savefig("MapB73_Uncorrected_PCA_28-Apr-2023.pdf",bbox_inches="tight")
plt.savefig("MapB73_Uncorrected_PCA_28-Apr-2023.png",bbox_inches="tight")

# %% [markdown]
# Re-run PCA but only on leaf data.

# %%
# subset vttpm_log_merged to only leaf samples
vttpm_log_leaf = vttpm_log_merged[vttpm_log_merged["Tissue"]=="Leaf"]

# %%
# list of samples for leaf:
leafsamp = list(vttpm_log_leaf["SRA_number"])
leafsamp
# Out:
# ['SRR15241108',
#  'SRR15241156',
#  'SRR8857746',
#  'SRR15241170',
#  'SRR2106196',
#  'SRR1819617',
#  'SRR15241104',
#  'SRR15241145',
#  'SRR2106184',
#  'SRR15241201',
#  'SRR15241167',
#  'SRR8857744',
#  'SRR15241274',
#  'SRR15241262',
#  'SRR1819621',
#  'SRR15241190',
#  'SRR8857774',
#  'SRR15241179',
#  'SRR1819198',
#  'SRR15241361',
#  'SRR8857825',
#  'SRR15241109',
#  'SRR15241168',
#  'SRR8857769',
#  'SRR8857831',
#  'SRR15241115',
#  'SRR2106200',
#  'SRR15241117',
#  'SRR8857762',
#  'SRR15241116',
#  'SRR15241384',
#  'SRR2106202',
#  'SRR15241362',
#  'SRR8857742',
#  'SRR15241111',
#  'SRR1238715',
#  'SRR8857768',
#  'SRR1238719',
#  'SRR15241250',
#  'SRR15241105',
#  'SRR8857772',
#  'SRR2106180',
#  'SRR1819196',
#  'SRR15241113',
#  'SRR1238718',
#  'SRR2106198',
#  'SRR8857773',
#  'SRR15241107',
#  'SRR15241212',
#  'SRR15241114',
#  'SRR15241112',
#  'SRR8857767',
#  'SRR15241296',
#  'SRR8857747',
#  'SRR15241106',
#  'SRR15241285',
#  'SRR2106182',
#  'SRR15241360',
#  'SRR8857771',
#  'SRR15241169',
#  'SRR8857826',
#  'SRR15241359',
#  'SRR2106186',
#  'SRR8857770',
#  'SRR15241373',
#  'SRR8857748',
#  'SRR8857832',
#  'SRR6807372',
#  'SRR2106197',
#  'SRR6335608',
#  'SRR13398925',
#  'SRR2144414',
#  'SRR925466',
#  'SRR15241301',
#  'SRR1819205',
#  'SRR13398924',
#  'SRR15241119',
#  'SRR13398918',
#  'SRR2144406',
#  'SRR2144399',
#  'SRR1819204',
#  'SRR12172978',
#  'SRR2144422',
#  'SRR15241120',
#  'SRR13398916',
#  'SRR12172977',
#  'SRR2106181',
#  'SRR2106201',
#  'SRR925464',
#  'SRR2144431',
#  'SRR2144441',
#  'SRR2144408',
#  'SRR6335607',
#  'SRR6335606',
#  'SRR6335609',
#  'SRR6807368',
#  'SRR2144425',
#  'SRR2144439',
#  'SRR13398919',
#  'SRR6335602',
#  'SRR2106185',
#  'SRR2144432',
#  'SRR2144417',
#  'SRR2144400',
#  'SRR2144438',
#  'SRR6807367',
#  'SRR925465',
#  'SRR11933245',
#  'SRR4054956',
#  'SRR2106187',
#  'SRR2106183',
#  'SRR1238720',
#  'SRR2144407',
#  'SRR2144390',
#  'SRR15241118',
#  'SRR13398921',
#  'SRR6807366',
#  'SRR2144430',
#  'SRR15241125',
#  'SRR15241297',
#  'SRR925463',
#  'SRR1238717',
#  'SRR6335599',
#  'SRR6335600',
#  'SRR2144424',
#  'SRR2144383',
#  'SRR6335605',
#  'SRR2144415',
#  'SRR2144391',
#  'SRR12172976',
#  'SRR15241171',
#  'SRR2144423',
#  'SRR2144440',
#  'SRR2144382',
#  'SRR15241126',
#  'SRR15241298',
#  'SRR15241312',
#  'SRR925468',
#  'SRR6807370',
#  'SRR6807371',
#  'SRR11933280',
#  'SRR4048280',
#  'SRR6335603',
#  'SRR2144409',
#  'SRR2144385',
#  'SRR925467',
#  'SRR13398923',
#  'SRR11933291',
#  'SRR15241172',
#  'SRR15241122',
#  'SRR2144384',
#  'SRR2144416',
#  'SRR2144393',
#  'SRR15241223',
#  'SRR2144398',
#  'SRR15241251',
#  'SRR6335610',
#  'SRR2106199',
#  'SRR12172975',
#  'SRR15241123',
#  'SRR6807369',
#  'SRR2144392',
#  'SRR2106203',
#  'SRR6807373',
#  'SRR15241124',
#  'SRR2144401',
#  'SRR2144433',
#  'SRR15241227',
#  'SRR15241219',
#  'SRR15241210',
#  'SRR15241345',
#  'SRR15241340',
#  'SRR15241351',
#  'SRR15241220',
#  'SRR15241356',
#  'SRR15241337',
#  'SRR15241228',
#  'SRR15241357',
#  'SRR15241353',
#  'SRR15241331',
#  'SRR15241215',
#  'SRR15241341',
#  'SRR15241231',
#  'SRR15241141',
#  'SRR15241343',
#  'SRR15241346',
#  'SRR15241352',
#  'SRR15241332',
#  'SRR15241217',
#  'SRR15241211',
#  'SRR15241216',
#  'SRR15241338',
#  'SRR15241143',
#  'SRR15241218',
#  'SRR15241333',
#  'SRR15241348',
#  'SRR15241225',
#  'SRR15241342',
#  'SRR15241354',
#  'SRR15241334',
#  'SRR15241213',
#  'SRR15241221',
#  'SRR15241142',
#  'SRR15241344',
#  'SRR15241229',
#  'SRR15241214',
#  'SRR15241230',
#  'SRR15241222',
#  'SRR15241339',
#  'SRR15241350',
#  'SRR15241335',
#  'SRR15241349',
#  'SRR15241226',
#  'SRR15241209',
#  'SRR15241355',
#  'SRR15241140',
#  'SRR15241224',
#  'SRR15241374',
#  'SRR11933090',
#  'SRR11933089',
#  'SRR15241375',
#  'SRR15241377',
#  'SRR15241376',
#  'SRR1663696',
#  'SRR15241245',
#  'SRR1663702',
#  'SRR1663706',
#  'SRR15241247',
#  'SRR15241246',
#  'SRR1663704',
#  'SRR1238724',
#  'SRR15241248',
#  'SRR1663701',
#  'SRR1663695',
#  'SRR1663705',
#  'SRR1663691',
#  'SRR1663698',
#  'SRR1663699',
#  'SRR15241287',
#  'SRR12214378',
#  'SRR12214356',
#  'SRR11933021',
#  'SRR12214375',
#  'SRR12214353',
#  'SRR15241322',
#  'SRR15241328',
#  'SRR15241205',
#  'SRR15241294',
#  'SRR12214376',
#  'SRR12214354',
#  'SRR15241283',
#  'SRR15241323',
#  'SRR15241286',
#  'SRR12214380',
#  'SRR11933023',
#  'SRR11933022',
#  'SRR15241290',
#  'SRR15241315',
#  'SRR15241282',
#  'SRR12214381',
#  'SRR15241207',
#  'SRR15241324',
#  'SRR15241288',
#  'SRR15241317',
#  'SRR12214372',
#  'SRR12214350',
#  'SRR15241316',
#  'SRR15241203',
#  'SRR15241206',
#  'SRR15241129',
#  'SRR12214373',
#  'SRR12214351',
#  'SRR15241284',
#  'SRR15241318',
#  'SRR15241202',
#  'SRR15241320',
#  'SRR12214349',
#  'SRR15241313',
#  'SRR12214379',
#  'SRR12214357',
#  'SRR15241208',
#  'SRR15241291',
#  'SRR12214358',
#  'SRR15241329',
#  'SRR12214355',
#  'SRR15241204',
#  'SRR15241289',
#  'SRR15241127',
#  'SRR15241200',
#  'SRR11933050',
#  'SRR15241293',
#  'SRR12214382',
#  'SRR15241130',
#  'SRR12214371',
#  'SRR11933025',
#  'SRR15241128',
#  'SRR15241330',
#  'SRR12214347',
#  'SRR15241292',
#  'SRR15241281',
#  'SRR15241321',
#  'SRR12214348',
#  'SRR15241327',
#  'SRR12214377',
#  'SRR15241326',
#  'SRR12214374',
#  'SRR12214352',
#  'SRR15241319']

# %%
# go back to transposed TPM file and subset to only leaf samples
ttpm.reset_index(inplace=True)
ttpml = ttpm[ttpm["index"].isin(leafsamp)]
ttpml.set_index("index",inplace=True)

# %%
ttpml.drop(["level_0"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 ttpml.drop(["level_0"],axis=1,inplace=True)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['level_0'] not found in axis"

# %%
vttpml = variance_threshold_selector(ttpml)
vttpml.head()
# Out:
# GeneID       Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# index
# SRR15241108        15.116249         0.808690         0.000000
# SRR15241156        13.781893         0.565147         0.000000
# SRR8857746         32.421567         1.344191         2.733165
# SRR15241170        13.266106         1.035099         0.000000
# SRR2106196          5.291619        18.872878         0.000000
#
# GeneID       Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# index
# SRR15241108        35.563727         0.000000        10.080573
# SRR15241156        18.684174         0.000000         9.818174
# SRR8857746         28.603220         0.000000        36.939687
# SRR15241170        22.302009         0.000000         7.056429
# SRR2106196          4.794730         1.360438         8.090446
#
# GeneID       Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# index
# SRR15241108         0.000000              0.0         0.288952
# SRR15241156         0.000000              0.0         0.000000
# SRR8857746          0.489093              0.0         1.580797
# SRR15241170         0.000000              0.0         0.000000
# SRR2106196          0.000000              0.0         0.792070
#
# GeneID       Zm00001eb000140  ...  Zm00001eb442830  Zm00001eb442840  \
# index                         ...
# SRR15241108              0.0  ...              0.0              0.0
# SRR15241156              0.0  ...              0.0              0.0
# SRR8857746               0.0  ...              0.0              0.0
# SRR15241170              0.0  ...              0.0              0.0
# SRR2106196               0.0  ...              0.0              0.0
#
# GeneID       Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# index
# SRR15241108              0.0         0.000000              0.0
# SRR15241156              0.0         0.228073              0.0
# SRR8857746               0.0         0.000000              0.0
# SRR15241170              0.0         0.000000              0.0
# SRR2106196               0.0         0.000000              0.0
#
# GeneID       Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  \
# index
# SRR15241108              0.0         0.480562              0.0
# SRR15241156              0.0         0.413354              0.0
# SRR8857746               0.0         0.379264              0.0
# SRR15241170              0.0         0.000000              0.0
# SRR2106196               0.0         0.168468              0.0
#
# GeneID       Zm00001eb442980  Zm00001eb443030
# index
# SRR15241108              0.0         0.000000
# SRR15241156              0.0         0.880361
# SRR8857746               0.0         0.000000
# SRR15241170              0.0         0.726964
# SRR2106196               0.0         0.327263
#
# [5 rows x 38456 columns]

# %%
len(ttpml.columns)-len(vttpml.columns)
# Out:
# 636

# %% [markdown]
# In this case, variance thresholding removed 636 genes.

# %%
vttpml_log = vttpml.apply(lambda x: np.log2(x+1))
vttpml_log.head()
# Out:
# GeneID       Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# index
# SRR15241108         4.010444         0.854945         0.000000
# SRR15241156         3.885759         0.646298         0.000000
# SRR8857746          5.062707         1.229090         1.900399
# SRR15241170         3.834520         1.025099         0.000000
# SRR2106196          2.653431         4.312729         0.000000
#
# GeneID       Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  \
# index
# SRR15241108         5.192341         0.000000         3.469961
# SRR15241156         4.298964         0.000000         3.435385
# SRR8857746          4.887682         0.000000         5.245636
# SRR15241170         4.542382         0.000000         3.010141
# SRR2106196          2.534741         1.239055         3.184351
#
# GeneID       Zm00001eb000100  Zm00001eb000110  Zm00001eb000120  \
# index
# SRR15241108         0.000000              0.0         0.366199
# SRR15241156         0.000000              0.0         0.000000
# SRR8857746          0.574434              0.0         1.367817
# SRR15241170         0.000000              0.0         0.000000
# SRR2106196          0.000000              0.0         0.841627
#
# GeneID       Zm00001eb000140  ...  Zm00001eb442830  Zm00001eb442840  \
# index                         ...
# SRR15241108              0.0  ...              0.0              0.0
# SRR15241156              0.0  ...              0.0              0.0
# SRR8857746               0.0  ...              0.0              0.0
# SRR15241170              0.0  ...              0.0              0.0
# SRR2106196               0.0  ...              0.0              0.0
#
# GeneID       Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# index
# SRR15241108              0.0         0.000000              0.0
# SRR15241156              0.0         0.296396              0.0
# SRR8857746               0.0         0.000000              0.0
# SRR15241170              0.0         0.000000              0.0
# SRR2106196               0.0         0.000000              0.0
#
# GeneID       Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  \
# index
# SRR15241108              0.0         0.566145              0.0
# SRR15241156              0.0         0.499123              0.0
# SRR8857746               0.0         0.463899              0.0
# SRR15241170              0.0         0.000000              0.0
# SRR2106196               0.0         0.224618              0.0
#
# GeneID       Zm00001eb442980  Zm00001eb443030
# index
# SRR15241108              0.0         0.000000
# SRR15241156              0.0         0.911010
# SRR8857746               0.0         0.000000
# SRR15241170              0.0         0.788238
# SRR2106196               0.0         0.408454
#
# [5 rows x 38456 columns]

# %%
pca = PCA(n_components=2)
real_PCs = pca.fit_transform(vttpml_log)
real_PCs_df = pd.DataFrame(data = real_PCs, columns = ['PC1','PC2'])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.2163491 , 0.14259103])

# %%
vttpml_log.reset_index(inplace=True)
vttpml_log.head()
# Out:
# GeneID        index  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0       SRR15241108         4.010444         0.854945         0.000000
# 1       SRR15241156         3.885759         0.646298         0.000000
# 2        SRR8857746         5.062707         1.229090         1.900399
# 3       SRR15241170         3.834520         1.025099         0.000000
# 4        SRR2106196         2.653431         4.312729         0.000000
#
# GeneID  Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0              5.192341         0.000000         3.469961         0.000000
# 1              4.298964         0.000000         3.435385         0.000000
# 2              4.887682         0.000000         5.245636         0.574434
# 3              4.542382         0.000000         3.010141         0.000000
# 4              2.534741         1.239055         3.184351         0.000000
#
# GeneID  Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442830  \
# 0                   0.0         0.366199  ...              0.0
# 1                   0.0         0.000000  ...              0.0
# 2                   0.0         1.367817  ...              0.0
# 3                   0.0         0.000000  ...              0.0
# 4                   0.0         0.841627  ...              0.0
#
# GeneID  Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# 0                   0.0              0.0         0.000000              0.0
# 1                   0.0              0.0         0.296396              0.0
# 2                   0.0              0.0         0.000000              0.0
# 3                   0.0              0.0         0.000000              0.0
# 4                   0.0              0.0         0.000000              0.0
#
# GeneID  Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  \
# 0                   0.0         0.566145              0.0              0.0
# 1                   0.0         0.499123              0.0              0.0
# 2                   0.0         0.463899              0.0              0.0
# 3                   0.0         0.000000              0.0              0.0
# 4                   0.0         0.224618              0.0              0.0
#
# GeneID  Zm00001eb443030
# 0              0.000000
# 1              0.911010
# 2              0.000000
# 3              0.788238
# 4              0.408454
#
# [5 rows x 38457 columns]

# %%
vttpml_log.rename(columns={"index":"SRA_number"},inplace=True)
vttpml_log.head()
# Out:
# GeneID   SRA_number  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0       SRR15241108         4.010444         0.854945         0.000000
# 1       SRR15241156         3.885759         0.646298         0.000000
# 2        SRR8857746         5.062707         1.229090         1.900399
# 3       SRR15241170         3.834520         1.025099         0.000000
# 4        SRR2106196         2.653431         4.312729         0.000000
#
# GeneID  Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0              5.192341         0.000000         3.469961         0.000000
# 1              4.298964         0.000000         3.435385         0.000000
# 2              4.887682         0.000000         5.245636         0.574434
# 3              4.542382         0.000000         3.010141         0.000000
# 4              2.534741         1.239055         3.184351         0.000000
#
# GeneID  Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442830  \
# 0                   0.0         0.366199  ...              0.0
# 1                   0.0         0.000000  ...              0.0
# 2                   0.0         1.367817  ...              0.0
# 3                   0.0         0.000000  ...              0.0
# 4                   0.0         0.841627  ...              0.0
#
# GeneID  Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# 0                   0.0              0.0         0.000000              0.0
# 1                   0.0              0.0         0.296396              0.0
# 2                   0.0              0.0         0.000000              0.0
# 3                   0.0              0.0         0.000000              0.0
# 4                   0.0              0.0         0.000000              0.0
#
# GeneID  Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  \
# 0                   0.0         0.566145              0.0              0.0
# 1                   0.0         0.499123              0.0              0.0
# 2                   0.0         0.463899              0.0              0.0
# 3                   0.0         0.000000              0.0              0.0
# 4                   0.0         0.224618              0.0              0.0
#
# GeneID  Zm00001eb443030
# 0              0.000000
# 1              0.911010
# 2              0.000000
# 3              0.788238
# 4              0.408454
#
# [5 rows x 38457 columns]

# %%
vttpml_log_merged = vttpml_log.merge(md,how="inner")
vttpml_log_merged.head()
# Out:
#     SRA_number  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0  SRR15241108         4.010444         0.854945         0.000000
# 1  SRR15241156         3.885759         0.646298         0.000000
# 2   SRR8857746         5.062707         1.229090         1.900399
# 3  SRR15241170         3.834520         1.025099         0.000000
# 4   SRR2106196         2.653431         4.312729         0.000000
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         5.192341         0.000000         3.469961         0.000000
# 1         4.298964         0.000000         3.435385         0.000000
# 2         4.887682         0.000000         5.245636         0.574434
# 3         4.542382         0.000000         3.010141         0.000000
# 4         2.534741         1.239055         3.184351         0.000000
#
#    Zm00001eb000110  Zm00001eb000120  ...  Developmental_stage  Tissue  \
# 0              0.0         0.366199  ...                V2/V3    Leaf
# 1              0.0         0.000000  ...                V2/V3    Leaf
# 2              0.0         1.367817  ...                   R1    Leaf
# 3              0.0         0.000000  ...                V2/V3    Leaf
# 4              0.0         0.841627  ...                V5/V6    Leaf
#
#    Day_length_hours  Day_temp_C  Night_temp_C  Relative humidity (%)  \
# 0              16.0        30.0          20.0                    NaN
# 1              16.0        39.0          29.0                    NaN
# 2              14.0        38.0           NaN                     65
# 3              16.0        30.0          20.0                    NaN
# 4               NaN        29.0          21.0                  60-80
#
#    Light (umol/m2/s)  Growth Env.  Media  Notes
# 0                NaN          NaN    NaN    NaN
# 1                NaN          NaN    NaN    NaN
# 2                NaN    Phytotron    NaN    NaN
# 3                NaN          NaN    NaN    NaN
# 4                NaN   Greenhouse    NaN    NaN
#
# [5 rows x 38478 columns]

# %%
lplotdf = pd.concat([real_PCs_df,vttpm_log_merged[["BioProject","Genotype","Treatment","Time_after_treatment","Concentration",
                                                 "Developmental_stage","Tissue","Day_length_hours","Day_temp_C","Night_temp_C",
                                                 "Relative humidity (%)","Light (umol/m2/s)","Growth Env.","Media"]]],axis=1)
lplotdf.head()
# Out:
#           PC1         PC2   BioProject Genotype Treatment  \
# 0  -31.630239  -37.023627  PRJNA520822      B73      Heat
# 1  -37.491015  -29.027652  PRJNA520822      B73   Control
# 2   51.867869  -85.599336  PRJNA747925      B73   Control
# 3  -43.322843  -27.450759  PRJNA747925      B73      Heat
# 4  126.437707  150.828590  PRJNA520822      B73      Heat
#
#   Time_after_treatment Concentration Developmental_stage  Tissue  \
# 0              2 hours           NaN                  V3   Stalk
# 1               0 hour           NaN                  V3    Root
# 2             25 hours           NaN               V2/V3    Leaf
# 3               1 hour           NaN               V2/V3    Leaf
# 4              2 hours           NaN                  R1  Tassel
#
#    Day_length_hours  Day_temp_C  Night_temp_C Relative humidity (%)  \
# 0              14.0        38.0           NaN                    65
# 1              14.0        25.0           NaN                    65
# 2              16.0        30.0          20.0                   NaN
# 3              16.0        39.0          29.0                   NaN
# 4              14.0        38.0           NaN                    65
#
#   Light (umol/m2/s) Growth Env. Media
# 0               NaN   Phytotron   NaN
# 1               NaN   Phytotron   NaN
# 2               NaN         NaN   NaN
# 3               NaN         NaN   NaN
# 4               NaN   Phytotron   NaN

# %%
# make subplots & color by different things: BioProject, treatment, day temperature, dev stage, growth env, genotype

fig,ax = plt.subplots(nrows=3,ncols=2,figsize = (15,20))

a = sns.scatterplot(ax=ax[0,0],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["BioProject"],palette="tab20",s=75,alpha=0.75)
a.set_title("By BioProject",fontsize=12)
a.legend(bbox_to_anchor=(-0.13,1.1))
b = sns.scatterplot(ax=ax[0,1],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["Treatment"],palette="tab20",s=75,alpha=0.75)
b.set_title("By Treatment",fontsize=12)
b.legend(bbox_to_anchor=(1.02,1.1))
sns.scatterplot(ax=ax[1,0],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["Genotype"],palette="tab10",s=75,alpha=0.75).set_title("By Genotype",fontsize=12)
d = sns.scatterplot(ax=ax[1,1],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["Developmental_stage"],palette="tab20",s=75,alpha=0.75)
d.set_title("By Dev. Stage",fontsize=12)
d.legend(bbox_to_anchor=(1.02,1.1))
sns.scatterplot(ax=ax[2,0],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["Day_temp_C"],palette="magma",s=75,alpha=0.75).set_title("By Day Temperature",fontsize=12)
sns.scatterplot(ax=ax[2,1],x=lplotdf["PC1"],y=lplotdf["PC2"],hue=lplotdf["Growth Env."],palette="tab10",s=75,alpha=0.75).set_title("By Environment",fontsize=12)

plt.savefig("Leaf_MapB73_Uncorrected_PCA_28-Apr-2023.pdf",bbox_inches="tight")
plt.savefig("Leaf_MapB73_Uncorrected_PCA_28-Apr-2023.png",bbox_inches="tight")

# %% [markdown]
# Next section: hierarchical clustering of stress response TPM in leaves and all tissues (start with all tissues).

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# need index to be the thing that you're clustering on
## try setting Treatment as index 
## cluster on log TPM
hclust_data = vttpm_log.merge(md[["SRA_number","Treatment"]],how="inner")
hclust_data.set_index("Treatment",inplace=True)
hclust_data.drop("SRA_number",axis=1,inplace=True)
hclust_data.head()
# Out:
#            Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  Zm00001eb000060  \
# Treatment
# Heat              3.244565         6.686657         0.578058         4.881669
# Control           1.232253         5.339633         0.000000         3.055128
# Control           4.010444         0.854945         0.000000         5.192341
# Heat              3.885759         0.646298         0.000000         4.298964
# Heat              2.553955         3.888335         0.603243         3.024108
#
#            Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  Zm00001eb000110  \
# Treatment
# Heat                   0.0         4.743440         0.475560              0.0
# Control                0.0         3.954630         1.022913              0.0
# Control                0.0         3.469961         0.000000              0.0
# Heat                   0.0         3.435385         0.000000              0.0
# Heat                   0.0         2.550187         0.130827              0.0
#
#            Zm00001eb000120  Zm00001eb000140  ...  Zm00001eb442830  \
# Treatment                                    ...
# Heat              1.029656              0.0  ...              0.0
# Control           0.000000              0.0  ...              0.0
# Control           0.366199              0.0  ...              0.0
# Heat              0.000000              0.0  ...              0.0
# Heat              0.466365              0.0  ...              0.0
#
#            Zm00001eb442840  Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  \
# Treatment
# Heat                   0.0              0.0         0.000000              0.0
# Control                0.0              0.0         0.000000              0.0
# Control                0.0              0.0         0.000000              0.0
# Heat                   0.0              0.0         0.296396              0.0
# Heat                   0.0              0.0         0.000000              0.0
#
#            Zm00001eb442890  Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  \
# Treatment
# Heat                   0.0         0.341713              0.0              0.0
# Control                0.0         2.617084              0.0              0.0
# Control                0.0         0.566145              0.0              0.0
# Heat                   0.0         0.499123              0.0              0.0
# Heat                   0.0         1.015209              0.0              0.0
#
#            Zm00001eb443030
# Treatment
# Heat               0.00000
# Control            0.00000
# Control            0.00000
# Heat               0.91101
# Heat               0.00000
#
# [5 rows x 38901 columns]

# %%
l = linkage(hclust_data,"ward")

# %%
plt.figure(figsize=(25,10))
d = dendrogram(l,labels=hclust_data.index,truncate_mode="lastp")
plt.show(d)
#plt.savefig("hclust_515mapB73.pdf")

# %%
# un-truncated dendrogram, vertical
plt.figure(figsize=(10,35))
dendrogram(l, labels=hclust_data.index, orientation="right")
plt.show()

# %%
# this is not what I wanted it to be. just for fun, let's try creating a sort of summary of the TPM for each treatment 
## overall, then do hclust and plot. 

# reset index
hclust_data.reset_index(inplace=True)
hclust_data.head()
# Out:
#   Treatment  Zm00001eb000010  Zm00001eb000020  Zm00001eb000050  \
# 0      Heat         3.244565         6.686657         0.578058
# 1   Control         1.232253         5.339633         0.000000
# 2   Control         4.010444         0.854945         0.000000
# 3      Heat         3.885759         0.646298         0.000000
# 4      Heat         2.553955         3.888335         0.603243
#
#    Zm00001eb000060  Zm00001eb000070  Zm00001eb000080  Zm00001eb000100  \
# 0         4.881669              0.0         4.743440         0.475560
# 1         3.055128              0.0         3.954630         1.022913
# 2         5.192341              0.0         3.469961         0.000000
# 3         4.298964              0.0         3.435385         0.000000
# 4         3.024108              0.0         2.550187         0.130827
#
#    Zm00001eb000110  Zm00001eb000120  ...  Zm00001eb442830  Zm00001eb442840  \
# 0              0.0         1.029656  ...              0.0              0.0
# 1              0.0         0.000000  ...              0.0              0.0
# 2              0.0         0.366199  ...              0.0              0.0
# 3              0.0         0.000000  ...              0.0              0.0
# 4              0.0         0.466365  ...              0.0              0.0
#
#    Zm00001eb442850  Zm00001eb442870  Zm00001eb442880  Zm00001eb442890  \
# 0              0.0         0.000000              0.0              0.0
# 1              0.0         0.000000              0.0              0.0
# 2              0.0         0.000000              0.0              0.0
# 3              0.0         0.296396              0.0              0.0
# 4              0.0         0.000000              0.0              0.0
#
#    Zm00001eb442940  Zm00001eb442960  Zm00001eb442980  Zm00001eb443030
# 0         0.341713              0.0              0.0          0.00000
# 1         2.617084              0.0              0.0          0.00000
# 2         0.566145              0.0              0.0          0.00000
# 3         0.499123              0.0              0.0          0.91101
# 4         1.015209              0.0              0.0          0.00000
#
# [5 rows x 38902 columns]

# %%
hclust_data["Treatment"].unique()
# Out:
# array(['Heat', 'Control', 'ControlRec', 'SaltRec', 'Salt', 'Low_Nitrogen',
#        'Drought', 'DroughtRec', 'Flooding', 'Cold', 'ColdDrought',
#        'ColdRec', 'DroughtSaltRec', 'DroughtSalt', 'UV', 'DroughtRepeat',
#        'ColdDroughtRec'], dtype=object)

# %%
# drop certain treatments 
hcd = hclust_data[hclust_data["Treatment"].isin(["Heat","Control","Salt","Low_Nitrogen","Drought","Flooding","Cold"])]

# %%
hcdg = hcd.groupby(by="Treatment",axis=0).mean()

# %%
k = linkage(hcdg,"ward")

# %%
plt.figure(figsize=(10,10))
dendrogram(k,labels=hcdg.index)
plt.show()

# %% [markdown]
# Jeremy suggests grouping by treatment and clustering on the 1st PC of each treatment.
