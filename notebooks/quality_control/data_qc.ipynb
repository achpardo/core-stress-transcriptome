# %% [markdown]
# Purpose: Do some quality control of TPM data and WGCNA outputs.<br>
# Author: Anna Pardo

# %%
# check that TPM are similar for tximport results with all samples and with only the samples for DE
# load pandas
import pandas as pd

# %%
# load old TPM
oldtpm = pd.read_csv("../data/TPM_LS_allsamp_05-May-2023.txt",sep="\t",header="infer",index_col="GeneID")
oldtpm.head()
# Out:
#                  SRR8857799  SRR8857793  SRR15241108  SRR15241156  SRR8857749  \
# GeneID
# Zm00001eb000010    8.477884    1.349336    15.116249    13.781893    4.872421
# Zm00001eb000020  102.011193   39.493900     0.808690     0.565147   13.808307
# Zm00001eb000050    0.492838    0.000000     0.000000     0.000000    0.519128
# Zm00001eb000060   28.480082    7.311609    35.563727    18.684174    7.134804
# Zm00001eb000070    0.000000    0.000000     0.000000     0.000000    0.000000
#
#                  SRR8857746  SRR15241170  SRR8857844  SRR9282931  SRR2106196  \
# GeneID
# Zm00001eb000010   32.421567    13.266106   10.918767    1.099232    5.291619
# Zm00001eb000020    1.344191     1.035099  124.754873   45.137300   18.872878
# Zm00001eb000050    2.733165     0.000000    1.152023    0.000000    0.000000
# Zm00001eb000060   28.603220    22.302009   34.742011    2.411356    4.794730
# Zm00001eb000070    0.000000     0.000000    0.000000    0.000000    1.360438
#
# ...

# %%
# load new TPM
newtpm = pd.read_csv("../data/TPM_LS_samples_for_DE_06-Jun-2023.txt",sep="\t",header="infer",index_col="GeneID")
newtpm.head()
# Out:
#                  SRR8857799  SRR8857793  SRR15241108  SRR15241156  SRR8857749  \
# GeneID
# Zm00001eb000010    8.477884    1.349336    15.116249    13.781893    4.872421
# Zm00001eb000020  102.011193   39.493900     0.808690     0.565147   13.808307
# Zm00001eb000050    0.492838    0.000000     0.000000     0.000000    0.519128
# Zm00001eb000060   28.480082    7.311609    35.563727    18.684174    7.134804
# Zm00001eb000070    0.000000    0.000000     0.000000     0.000000    0.000000
#
#                  SRR8857746  SRR15241170  SRR8857844  SRR9282931  SRR1819617  \
# GeneID
# Zm00001eb000010   32.421567    13.266106   10.918767    1.099232   14.896881
# Zm00001eb000020    1.344191     1.035099  124.754873   45.137300   27.587733
# Zm00001eb000050    2.733165     0.000000    1.152023    0.000000    0.264015
# Zm00001eb000060   28.603220    22.302009   34.742011    2.411356   49.961373
# Zm00001eb000070    0.000000     0.000000    0.000000    0.000000    8.906430
#
# ...

# %%
# looks good!

# %%
## check that WGCNA data are OK
wgcna = pd.read_csv("../data/rawtpm_forWGCNA_noPEG.tsv",sep="\t",header="infer")
wgcna.head()
# Out:
#             GeneID  SRR11933261  SRR11933272  SRR11933250  SRR11933029  \
# 0  Zm00001eb000010    12.553818    16.255838     9.028815     8.201340
# 1  Zm00001eb000020     2.321077     3.110372     2.984479     2.385748
# 2  Zm00001eb000050     0.042520     0.405226     0.000000     0.000000
# 3  Zm00001eb000060    12.932676     7.214039     3.092442     1.726808
# 4  Zm00001eb000070     5.253755     1.902461     2.586555     1.926412
#
#    SRR11933040  SRR11932822  SRR11932811  SRR11933230  SRR11932879  ...  \
# 0    10.371251    37.430009    39.925873    30.677016    23.393003  ...
# 1     2.799099    27.508819    22.440680    24.648455     7.595576  ...
# 2     0.000000     0.000000     0.000000     0.000000     0.304751  ...
# 3     1.280629    29.510498    22.148225    22.170584    14.727189  ...
# 4     3.771234     7.005587     7.590336     5.274585     2.177748  ...
#
#     Ms71D3C    Ki3D1C  CML228D1D  CML333D3D  MO18WD3C    B73D3C  NC358D3C  \
# ...
