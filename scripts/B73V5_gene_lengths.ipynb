# %% [markdown]
# Purpose: Extract gene lengths from gff file for B73 V5 so I can convert count data from Brandon Webster into TPM.<br>
# Author: Anna Pardo<br>
# Date initiated: May 11, 2023

# %%
# import modules
import pandas as pd

# %%
# read in gff file
gff = pd.read_csv("../data/Zm-B73-REFERENCE-NAM-5.0_Zm00001eb.1.gff",sep="\t",header=None,comment="#")
gff.head()
# Out:
#       0         1               2      3          4  5  6  7  \
# 0  chr1  assembly      chromosome      1  308452471  .  .  .
# 1  chr1       NAM            gene  34617      40204  .  +  .
# 2  chr1       NAM            mRNA  34617      40204  .  +  .
# 3  chr1       NAM  five_prime_UTR  34617      34721  .  +  .
# 4  chr1       NAM            exon  34617      35318  .  +  .
#
#                                                    8
# 0  ID=1;Name=chromosome:Zm-B73-REFERENCE-NAM-5.0:...
# 1  ID=Zm00001eb000010;biotype=protein_coding;logi...
# 2  ID=Zm00001eb000010_T001;Parent=Zm00001eb000010...
# 3                        Parent=Zm00001eb000010_T001
# 4  Parent=Zm00001eb000010_T001;Name=Zm00001eb0000...

# %%
# subset to type gene only
genes = gff[gff[2]=="gene"]
genes.head()
# Out:
#         0    1     2       3       4  5  6  7  \
# 1    chr1  NAM  gene   34617   40204  .  +  .
# 23   chr1  NAM  gene   41214   46762  .  -  .
# 106  chr1  NAM  gene  108554  114382  .  -  .
# 123  chr1  NAM  gene  188559  189581  .  -  .
# 131  chr1  NAM  gene  190192  198832  .  -  .
#
#                                                      8
# 1    ID=Zm00001eb000010;biotype=protein_coding;logi...
# 23   ID=Zm00001eb000020;biotype=protein_coding;logi...
# 106  ID=Zm00001eb000050;biotype=protein_coding;logi...
# 123  ID=Zm00001eb000060;biotype=protein_coding;logi...
# 131  ID=Zm00001eb000070;biotype=protein_coding;logi...

# %%
# extract gene ID as separate column
ids = []
for i in range(len(genes.index)):
    ids.append(genes.iloc[i,8].strip().split(";")[0].split("=")[1])

# %%
# add ID as column
genes[9]=ids
genes.head()
# Out:
# /tmp/ipykernel_1087/506937877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genes[9]=ids
#         0    1     2       3       4  5  6  7  \
# 1    chr1  NAM  gene   34617   40204  .  +  .
# 23   chr1  NAM  gene   41214   46762  .  -  .
# 106  chr1  NAM  gene  108554  114382  .  -  .
# 123  chr1  NAM  gene  188559  189581  .  -  .
# 131  chr1  NAM  gene  190192  198832  .  -  .
#
#                                                      8                9
# 1    ID=Zm00001eb000010;biotype=protein_coding;logi...  Zm00001eb000010
# 23   ID=Zm00001eb000020;biotype=protein_coding;logi...  Zm00001eb000020
# 106  ID=Zm00001eb000050;biotype=protein_coding;logi...  Zm00001eb000050
# 123  ID=Zm00001eb000060;biotype=protein_coding;logi...  Zm00001eb000060
# 131  ID=Zm00001eb000070;biotype=protein_coding;logi...  Zm00001eb000070

# %%
# calculate length
genes[10] = genes[4]-genes[3]
genes.head()
# Out:
# /tmp/ipykernel_1087/432189520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genes[10] = genes[4]-genes[3]
#        0    1     2       3       4  5  6  7   \
# 1    chr1  NAM  gene   34617   40204  .  +  .
# 23   chr1  NAM  gene   41214   46762  .  -  .
# 106  chr1  NAM  gene  108554  114382  .  -  .
# 123  chr1  NAM  gene  188559  189581  .  -  .
# 131  chr1  NAM  gene  190192  198832  .  -  .
#
#                                                     8                9     10
# 1    ID=Zm00001eb000010;biotype=protein_coding;logi...  Zm00001eb000010  5587
# 23   ID=Zm00001eb000020;biotype=protein_coding;logi...  Zm00001eb000020  5548
# 106  ID=Zm00001eb000050;biotype=protein_coding;logi...  Zm00001eb000050  5828
# 123  ID=Zm00001eb000060;biotype=protein_coding;logi...  Zm00001eb000060  1022
# 131  ID=Zm00001eb000070;biotype=protein_coding;logi...  Zm00001eb000070  8640

# %%
# subset dataframe & rename columns
df = genes[[9,10]]
df.rename(columns={9:"GeneID",10:"Length"},inplace=True)
df.head()
# Out:
# /tmp/ipykernel_1087/568170056.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={9:"GeneID",10:"Length"},inplace=True)
#               GeneID  Length
# 1    Zm00001eb000010    5587
# 23   Zm00001eb000020    5548
# 106  Zm00001eb000050    5828
# 123  Zm00001eb000060    1022
# 131  Zm00001eb000070    8640

# %%
# save dataframe
df.to_csv("../data/gene_lengths_B73V5.txt",sep="\t",header=True,index=False)
